# %% [markdown]
# <a href="https://colab.research.google.com/github/ajithaelavarasan/Computational-Thinking/blob/main/CONTROLSOM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#CONTROL SOM
from minisom import MiniSom    
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
from sklearn.datasets import load_digits
from pylab import plot,axis,show,pcolor,colorbar,bone
data= pd.read_csv('/dataset_after_data_aggregation.csv')
som = MiniSom(5, 5, 1, sigma=0.5, learning_rate=0.1)
X=data.iloc[:, [10]].values
labels=X
som.random_weights_init(X)
print("Initiating SOM.")
#som.train_random(X,100) 
som.train_batch(X,100) 
print("\n. SOM Processing Complete")
pcolor(som.distance_map().T) 
colorbar()
print(som.distance_map().T)
markers = ['o', '1', '^', 'h', 'X', 's', 'p', 'P', 'D', '*']
colors = ["r", "g", "b", "y", "c", (0,0.1,0.8), (1,0.5,0), (1,1,0.3), "m", (0.4,0.6,0)]
y=[]
for x in data.Game:
   y.append(x)
for x in range(0,10):
     print(x,markers[x])
pcolor(som.distance_map().T) 
j=0.0001
for i,x in enumerate(X):
    w=som.winner(x)
    plot(w[0]+j,
         w[1]+j,
        markers[y[i]-1],
        markeredgecolor=colors[y[i]-1],markerfacecolor='None',markersize=10,markeredgewidth=2)
    j=j+0.0009
    
          
show()
pcolor(som.distance_map().T) 
j=0.01
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[0]<10):
      plot(w[0]+j,
         w[1]+j,
        markers[0],
        markeredgecolor=colors[0],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.002
    
            
show()
pcolor(som.distance_map().T) 
j=0.01
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[0]<20 and x[0]>9):
      plot(w[0]+j,
         w[1]+j,
        markers[1],
        markeredgecolor=colors[1],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.002
    
show()
pcolor(som.distance_map().T) 
j=0.01
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[0]<30 and x[0]>19):
      plot(w[0]+j,
         w[1]+j,
        markers[2],
        markeredgecolor=colors[2],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.002
     
            
show()
pcolor(som.distance_map().T) 
j=0.01
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[0]<40 and x[0]>29):
      plot(w[0]+j,
         w[1]+j,
        markers[3],
        markeredgecolor=colors[3],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.002
     
show()
pcolor(som.distance_map().T) 
j=0.01
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[0]<50 and x[0]>39):
      plot(w[0]+j,
         w[1]+j,
        markers[4],
        markeredgecolor=colors[4],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.005
      
show()
pcolor(som.distance_map().T) 
j=0.01
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[0]<60 and x[0]>49):
      plot(w[0]+j,
         w[1]+j,
        markers[5],
        markeredgecolor=colors[5],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.005       
show()
pcolor(som.distance_map().T) 
j=0.01
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[0]<70 and x[0]>59):
      plot(w[0]+j,
         w[1]+j,
        markers[6],
        markeredgecolor=colors[6],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.005
     
            
show()
pcolor(som.distance_map().T) 
j=0.01
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[0]<80 and x[0]>69):
      plot(w[0]+j,
         w[1]+j,
        markers[7],
        markeredgecolor=colors[7],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.05
    
show()
pcolor(som.distance_map().T) 
j=0.01
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[0]<90 and x[0]>79):
      plot(w[0]+j,
         w[1]+j,
        markers[8],
        markeredgecolor=colors[8],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.05
    
show()
pcolor(som.distance_map().T) 
j=0.01
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[0]<100 and x[0]>89):
      plot(w[0]+j,
         w[1]+j,
        markers[9],
        markeredgecolor=colors[9],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.05
     
show()
# Out:
# Initiating SOM.
#
# . SOM Processing Complete
# [[0.36456666 0.26532404 0.16883785 0.30539509 0.21275636]
#  [0.4224731  0.7376411  0.56527489 0.48440474 0.57559567]
#  [1.         0.70967129 0.95686612 0.50535099 0.24612063]
#  [0.51400404 0.56899871 0.48653993 0.40821981 0.07744381]
#  [0.18422572 0.46945711 0.28777811 0.28309666 0.06738045]]
# 0 o
# 1 1
# 2 ^
# 3 h
# 4 X
# 5 s
# 6 p
# 7 P
# 8 D
# 9 *
