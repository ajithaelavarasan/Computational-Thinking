# %% [markdown]
# <a href="https://colab.research.google.com/github/ajithaelavarasan/Computational-Thinking/blob/main/KMEAN_SC_TRAIN_TEST_SPLIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#KMEAN SC TRAIN TEST SPLIT
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
from sklearn.model_selection import train_test_split
dataset= pd.read_csv('/dataset_after_data_aggregation.csv')
X=dataset.iloc[:, [0,15]].values
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=40)
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

X_train=ss.fit_transform(X_train)
X_test=ss.fit_transform(X_test)
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=8, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X_train)
#dataset['cluster']=y_kmeans
plt.scatter(X_train[y_kmeans==0, 0], X_train[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X_train[y_kmeans==1, 0], X_train[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X_train[y_kmeans==2, 0], X_train[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X_train[y_kmeans==3, 0], X_train[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X_train[y_kmeans==4, 0], X_train[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')
plt.scatter(X_train[y_kmeans==5, 0], X_train[y_kmeans==5, 1], s=10, c='grey', label ='Cluster 6')
plt.scatter(X_train[y_kmeans==6, 0], X_train[y_kmeans==6, 1], s=10, c='lime', label ='Cluster 7')
plt.scatter(X_train[y_kmeans==7, 0], X_train[y_kmeans==7, 1], s=10, c='gold', label ='Cluster 8')
plt.scatter(X_train[y_kmeans==8, 0], X_train[y_kmeans==8, 1], s=10, c='orange', label ='Cluster 9')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=25, c='yellow', label = 'Centroids')
plt.title('Clusters')
plt.xlabel('SC')
plt.ylabel('TC')
plt.show()
kmeans = KMeans(n_clusters=8, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X_test)
#dataset['cluster']=y_kmeans
plt.scatter(X_test[y_kmeans==0, 0], X_test[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X_test[y_kmeans==1, 0], X_test[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X_test[y_kmeans==2, 0], X_test[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X_test[y_kmeans==3, 0], X_test[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X_test[y_kmeans==4, 0], X_test[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')
plt.scatter(X_test[y_kmeans==5, 0], X_test[y_kmeans==5, 1], s=10, c='grey', label ='Cluster 6')
plt.scatter(X_test[y_kmeans==6, 0], X_test[y_kmeans==6, 1], s=10, c='lime', label ='Cluster 7')
plt.scatter(X_test[y_kmeans==7, 0], X_test[y_kmeans==7, 1], s=10, c='gold', label ='Cluster 8')
plt.scatter(X_test[y_kmeans==8, 0], X_test[y_kmeans==8, 1], s=10, c='orange', label ='Cluster 9')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=25, c='yellow', label = 'Centroids')
plt.title('Clusters')
plt.xlabel('SC')
plt.ylabel('TC')
plt.show()
kmeans = KMeans(n_clusters=8, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
#dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')
plt.scatter(X[y_kmeans==5, 0], X[y_kmeans==5, 1], s=10, c='grey', label ='Cluster 6')
plt.scatter(X[y_kmeans==6, 0], X[y_kmeans==6, 1], s=10, c='lime', label ='Cluster 7')
plt.scatter(X[y_kmeans==7, 0], X[y_kmeans==7, 1], s=10, c='gold', label ='Cluster 8')
plt.scatter(X[y_kmeans==8, 0], X[y_kmeans==8, 1], s=10, c='orange', label ='Cluster 9')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=25, c='yellow', label = 'Centroids')
plt.title('Clusters')
plt.xlabel('SC')
plt.ylabel('TC')
plt.show()
