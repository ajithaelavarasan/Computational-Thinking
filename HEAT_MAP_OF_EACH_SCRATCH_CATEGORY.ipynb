# %% [markdown]
# <a href="https://colab.research.google.com/github/ajithaelavarasan/Computational-Thinking/blob/main/HEAT_MAP_OF_EACH_SCRATCH_CATEGORY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#HEAT MAP OF EACH SCRATCH CATEGORY
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_data_aggregation.csv')
emp=[]
for x in data.Motion:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)
emp=[]

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_data_aggregation.csv')
emp=[]
for x in data.Looks:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)
emp=[]

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_data_aggregation.csv')
emp=[]
for x in data.Sound:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_data_aggregation.csv')
emp=[]
for x in data.Events:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)
emp=[]

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_data_aggregation.csv')
emp=[]
for x in data.Control:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)
emp=[]

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_data_aggregation.csv')
emp=[]
for x in data.Sensing:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)
emp=[]

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_data_aggregation.csv')
emp=[]
for x in data.Operators:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)
emp=[]

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_data_aggregation.csv')
emp=[]
for x in data.Variables:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)
emp=[]

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_data_aggregation.csv')
emp=[]
for x in data.Myblocks:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_data_aggregation.csv')
emp=[]
for x in data.TotalCommands:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_data_aggregation.csv')
emp=[]
for x in data.SumCommands:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import pandas as pd
data = pd.read_csv('/dataset_after_clustering.csv')
emp=[]
for x in data.cluster:
  emp.append(x)
emp=np.array(emp).reshape(25,33)
ax = sns.heatmap(emp,square=True)
