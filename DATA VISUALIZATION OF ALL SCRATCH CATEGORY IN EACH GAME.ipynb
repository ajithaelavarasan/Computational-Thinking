# %% [markdown]
# <a href="https://colab.research.google.com/github/ajithaelavarasan/Computational-Thinking/blob/main/DATA%20VISUALIZATION%20OF%20ALL%20SCRATCH%20CATEGORY%20IN%20EACH%20GAME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DATA VISUALIZATION OF ALL SCRATCH CATEGORY IN EACH GAME
import numpy
import pandas as pd
import seaborn as sns;
data = pd.read_csv('/dataset_after_data_aggregation.csv')
sns.jointplot(data=data,x='Game', y='SumCommands', hue='Game')
sns.jointplot(data=data,x='Game', y='Sprites', hue='Game' )
sns.jointplot(data=data,x='Game', y='Costumes', hue='Game' )
sns.jointplot(data=data,x='Game', y='BackDrops', hue='Game' )
sns.jointplot(data=data,x='Game', y='Motion', hue='Game' )
sns.jointplot(data=data,x='Game', y='Looks', hue='Game' )
sns.jointplot(data=data,x='Game', y='Control', hue='Game' )
sns.jointplot(data=data,x='Game', y='Sound', hue='Game' )
sns.jointplot(data=data,x='Game', y='Sensing', hue='Game' )
sns.jointplot(data=data,x='Game', y='Events', hue='Game' )
sns.jointplot(data=data,x='Game', y='Operators', hue='Game' )
sns.jointplot(data=data,x='Game', y='Variables', hue='Game' )
sns.jointplot(data=data,x='Game', y='Myblocks', hue='Game' )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...
