# %% [markdown]
# <a href="https://colab.research.google.com/github/ajithaelavarasan/Computational-Thinking/blob/main/DATA_VISUALIZATION_USAGE_OF_ALL_SCRATCH_CATEGORY_IN_EACH_GAME(BINARY).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DATA VISUALIZATION USAGE OF ALL SCRATCH CATEGORY IN EACH GAME
import plotly.graph_objects as go
import pandas as pd
import sys 
from termcolor import colored, cprint
print_red_on_blue = lambda x: cprint(x,'red', 'on_blue') 
print_red_on_blue('  ')
print('BinaryMotion')
print_red_on_green= lambda x: cprint(x,'red', 'on_green') 
print_red_on_green('  ')
print('BinaryLooks')
print_red_on_red = lambda x: cprint(x,'red', 'on_red') 
print_red_on_red('  ')
print('BinarySound')
print_red_on_cyan = lambda x: cprint(x,'red', 'on_cyan') 
print_red_on_cyan('  ')
print('BinaryEvents')
print_red_on_magenta = lambda x: cprint(x,'red', 'on_magenta') 
print_red_on_magenta('  ')
print('BinaryControl')
print_red_on_grey = lambda x: cprint(x,'red', 'on_grey') 
print_red_on_grey('  ')
print('BinarySensing')
print_red_on_yellow = lambda x: cprint(x,'red', 'on_yellow') 
print_red_on_yellow('  ')
print('BinaryOperators')
print_red_on_white = lambda x: cprint(x,'red', 'on_white') 
print_red_on_white('  ')
print('BinaryVariables')
print_red_on_cyan = lambda x: cprint(x,'red', 'on_cyan') 
print_red_on_cyan('  ')
print('BinaryMyblocks')

# Game1
data = pd.read_csv('/game1.csv')  
sm=data.BinaryMotion.sum(axis=0)
print(sm)
se=data.BinaryEvents.sum(axis=0)
print(se)
sc=data.BinaryControl.sum(axis=0)
print(sc)
ss=data.BinarySound.sum(axis=0)
print(ss)
sl=data.BinaryLooks.sum(axis=0)
print(sl)
ssn=data.BinarySensing.sum(axis=0)
print(ssn)
so=data.BinaryOperators.sum(axis=0)
print(so)
sv=data.BinaryVariables.sum(axis=0)
print(sv)
smb=data.BinaryMyblocks.sum(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
 name= 'radius=8'
 ))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 2
data = pd.read_csv('/game2.csv')  
sm=data.BinaryMotion.sum(axis=0)
print(sm)
se=data.BinaryEvents.sum(axis=0)
print(se)
sc=data.BinaryControl.sum(axis=0)
print(sc)
ss=data.BinarySound.sum(axis=0)
print(ss)
sl=data.BinaryLooks.sum(axis=0)
print(sl)
ssn=data.BinarySensing.sum(axis=0)
print(ssn)
so=data.BinaryOperators.sum(axis=0)
print(so)
sv=data.BinaryVariables.sum(axis=0)
print(sv)
smb=data.BinaryMyblocks.sum(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
 name= 'radius=20'

    #opacity=0.8
))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 3
data = pd.read_csv('/game3.csv')  
sm=data.BinaryMotion.sum(axis=0)
print(sm)
se=data.BinaryEvents.sum(axis=0)
print(se)
sc=data.BinaryControl.sum(axis=0)
print(sc)
ss=data.BinarySound.sum(axis=0)
print(ss)
sl=data.BinaryLooks.sum(axis=0)
print(sl)
ssn=data.BinarySensing.sum(axis=0)
print(ssn)
so=data.BinaryOperators.sum(axis=0)
print(so)
sv=data.BinaryVariables.sum(axis=0)
print(sv)
smb=data.BinaryMyblocks.sum(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=15'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 4
data = pd.read_csv('/game4.csv')  
sm=data.BinaryMotion.sum(axis=0)
print(sm)
se=data.BinaryEvents.sum(axis=0)
print(se)
sc=data.BinaryControl.sum(axis=0)
print(sc)
ss=data.BinarySound.sum(axis=0)
print(ss)
sl=data.BinaryLooks.sum(axis=0)
print(sl)
ssn=data.BinarySensing.sum(axis=0)
print(ssn)
so=data.BinaryOperators.sum(axis=0)
print(so)
sv=data.BinaryVariables.sum(axis=0)
print(sv)
smb=data.BinaryMyblocks.sum(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=27'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 5
data = pd.read_csv('/game5.csv')  
sm=data.BinaryMotion.sum(axis=0)
print(sm)
se=data.BinaryEvents.sum(axis=0)
print(se)
sc=data.BinaryControl.sum(axis=0)
print(sc)
ss=data.BinarySound.sum(axis=0)
print(ss)
sl=data.BinaryLooks.sum(axis=0)
print(sl)
ssn=data.BinarySensing.sum(axis=0)
print(ssn)
so=data.BinaryOperators.sum(axis=0)
print(so)
sv=data.BinaryVariables.sum(axis=0)
print(sv)
smb=data.BinaryMyblocks.sum(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=25'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 6
data = pd.read_csv('/game6.csv')  
sm=data.BinaryMotion.sum(axis=0)
print(sm)
se=data.BinaryEvents.sum(axis=0)
print(se)
sc=data.BinaryControl.sum(axis=0)
print(sc)
ss=data.BinarySound.sum(axis=0)
print(ss)
sl=data.BinaryLooks.sum(axis=0)
print(sl)
ssn=data.BinarySensing.sum(axis=0)
print(ssn)
so=data.BinaryOperators.sum(axis=0)
print(so)
sv=data.BinaryVariables.sum(axis=0)
print(sv)
smb=data.BinaryMyblocks.sum(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=50'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 7
data = pd.read_csv('/game7.csv')  
sm=data.BinaryMotion.sum(axis=0)
print(sm)
se=data.BinaryEvents.sum(axis=0)
print(se)
sc=data.BinaryControl.sum(axis=0)
print(sc)
ss=data.BinarySound.sum(axis=0)
print(ss)
sl=data.BinaryLooks.sum(axis=0)
print(sl)
ssn=data.BinarySensing.sum(axis=0)
print(ssn)
so=data.BinaryOperators.sum(axis=0)
print(so)
sv=data.BinaryVariables.sum(axis=0)
print(sv)
smb=data.BinaryMyblocks.sum(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=150'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 8
data = pd.read_csv('/game8.csv')  
sm=data.BinaryMotion.sum(axis=0)
print(sm)
se=data.BinaryEvents.sum(axis=0)
print(se)
sc=data.BinaryControl.sum(axis=0)
print(sc)
ss=data.BinarySound.sum(axis=0)
print(ss)
sl=data.BinaryLooks.sum(axis=0)
print(sl)
ssn=data.BinarySensing.sum(axis=0)
print(ssn)
so=data.BinaryOperators.sum(axis=0)
print(so)
sv=data.BinaryVariables.sum(axis=0)
print(sv)
smb=data.BinaryMyblocks.sum(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=60'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 9
data = pd.read_csv('/game9.csv')  
sm=data.BinaryMotion.sum(axis=0)
print(sm)
se=data.BinaryEvents.sum(axis=0)
print(se)
sc=data.BinaryControl.sum(axis=0)
print(sc)
ss=data.BinarySound.sum(axis=0)
print(ss)
sl=data.BinaryLooks.sum(axis=0)
print(sl)
ssn=data.BinarySensing.sum(axis=0)
print(ssn)
so=data.BinaryOperators.sum(axis=0)
print(so)
sv=data.BinaryVariables.sum(axis=0)
print(sv)
smb=data.BinaryMyblocks.sum(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=10'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 10
data = pd.read_csv('/game10.csv')  
sm=data.BinaryMotion.sum(axis=0)
print(sm)
se=data.BinaryEvents.sum(axis=0)
print(se)
sc=data.BinaryControl.sum(axis=0)
print(sc)
ss=data.BinarySound.sum(axis=0)
print(ss)
sl=data.BinaryLooks.sum(axis=0)
print(sl)
ssn=data.BinarySensing.sum(axis=0)
print(ssn)
so=data.BinaryOperators.sum(axis=0)
print(so)
sv=data.BinaryVariables.sum(axis=0)
print(sv)
smb=data.BinaryMyblocks.sum(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=150'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Out:
#
# BinaryMotion
#
# BinaryLooks
#
# BinarySound
#
# BinaryEvents
#
# BinaryControl
#
# BinarySensing
#
# BinaryOperators
#
# BinaryVariables
#
# BinaryMyblocks
# 80
# 80
# 80
# 78
# 80
# 80
# 80
# 73
# 54
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ede083e4-814d-487c-b95a-d820824a82df" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...
