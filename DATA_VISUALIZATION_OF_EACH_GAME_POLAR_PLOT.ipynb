# %% [markdown]
# <a href="https://colab.research.google.com/github/ajithaelavarasan/Computational-Thinking/blob/main/DATA_VISUALIZATION_OF_EACH_GAME_POLAR_PLOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DATA VISUALIZATION OF  EACH GAME
import plotly.graph_objects as go
import pandas as pd
import sys 
from termcolor import colored, cprint
print_red_on_blue = lambda x: cprint(x,'red', 'on_blue') 
print_red_on_blue('  ')
print('Motion')
print_red_on_green= lambda x: cprint(x,'red', 'on_green') 
print_red_on_green('  ')
print('Looks')
print_red_on_red = lambda x: cprint(x,'red', 'on_red') 
print_red_on_red('  ')
print('Sound')
print_red_on_cyan = lambda x: cprint(x,'red', 'on_cyan') 
print_red_on_cyan('  ')
print('Events')
print_red_on_magenta = lambda x: cprint(x,'red', 'on_magenta') 
print_red_on_magenta('  ')
print('Control')
print_red_on_grey = lambda x: cprint(x,'red', 'on_grey') 
print_red_on_grey('  ')
print('Sensing')
print_red_on_yellow = lambda x: cprint(x,'red', 'on_yellow') 
print_red_on_yellow('  ')
print('Operators')
print_red_on_white = lambda x: cprint(x,'red', 'on_white') 
print_red_on_white('  ')
print('Variables')
print_red_on_cyan = lambda x: cprint(x,'red', 'on_cyan') 
print_red_on_cyan('  ')
print('MyBlocks')

# Game1
data = pd.read_csv('/game1.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
sdsm=data.Motion.std(axis=0)
se=data.Events.mean(axis=0)
print(se)
sdse=data.Events.std(axis=0)
sc=data.Control.mean(axis=0)
print(sc)
sdsc=data.Control.std(axis=0)
ss=data.Sound.mean(axis=0)
print(ss)
sdss=data.Sound.std(axis=0)
sl=data.Looks.mean(axis=0)
print(sl)
sdsl=data.Looks.std(axis=0)
ssn=data.Sensing.mean(axis=0)
print(ssn)
sdssn=data.Sensing.std(axis=0)
so=data.Operators.mean(axis=0)
print(so)
sdso=data.Operators.std(axis=0)
sv=data.Variables.mean(axis=0)
print(sv)
sdsv=data.Variables.std(axis=0)
smb=data.Myblocks.mean(axis=0)
print(smb)
sdsmb=data.Myblocks.std(axis=0)
stc=data.TotalCommands.mean(axis=0)
sdstc=data.TotalCommands.std(axis=0)
ssp=data.Sprites.mean(axis=0)
sdssp=data.Sprites.std(axis=0)
scs=data.Costumes.mean(axis=0)
sdscs=data.Costumes.std(axis=0)
sb=data.BackDrops.mean(axis=0)
sdsb=data.BackDrops.std(axis=0)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
 name= 'radius=8'
 ))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 8], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()

output=[]
i=0
for x in data.Sprites:
    if(x> ssp- 2 * sdssp)and(x < ssp+ 2 * sdssp):
        i=i+1
        if(x> ssp-sdssp)and(x < ssp+sdssp):           
          i=i+2              
          if(x> ssp-0.5*sdssp)and(x < ssp+0.5*sdssp):
            i=i+1
            if(x==ssp):
             i=i+1
    output.append(i)  
    i=0          
data['CTSprites']=output
output=[]
i=0
for x in data.Costumes:
    if(x> scs- 2 * sdscs)and(x < scs+ 2 * sdscs):
        i=i+1
        if(x> scs-sdscs)and(x < scs+sdscs):
          i=i+2 
          if(x> scs-0.5*sdscs)and(x < scs+0.5*sdscs):
           i=i+1       
           if(x==scs):
             i=i+1
    output.append(i)  
    i=0          
data['CTCostumes']=output
output=[]
i=0
for x in data.BackDrops:
    if(x> sb- 2 * sdsb)and(x < sb+ 2 * sdsb):
        i=i+1
        if(x> sb-sdsb)and(x < sb+sdsb):
          i=i+2  
          if(x> sb-0.5*sdsb)and(x < sb+0.5*sdsb):
             i=i+1  
             if(x==sb):
                i=i+1
    output.append(i)  
    i=0          
data['CTBackdrops']=output
output=[]
i=0
for x in data.Motion:
    if(x> sm- 2 * sdsm)and(x < sm+ 2 * sdsm):
        i=i+1
        if(x> sm-sdsm)and(x < sm+sdsm):
          i=i+2 
          if(x> sm-0.5*sdsm)and(x < sm+0.5*sdsm):   
           i=i+1
           if(x==sm):
            i=i+1
    output.append(i)  
    i=0          
data['CTMotion']=output
output=[]
i=0
for x in data.Looks:
    if(x> sl- 2 * sdsl)and(x < sl+ 2 * sdsl):
        i=i+1
        if(x> sl-sdsl)and(x < sl+sdsl):
          i=i+2
          if(x> sl-0.5*sdsl)and(x < sl+0.5*sdsl):    
           i=i+1
           if(x==sl):
            i=i+1
    output.append(i)  
    i=0          
data['CTLooks']=output
output=[]
i=0
for x in data.Sensing:
    if(x> ssn- 2 * sdssn)and(x < ssn+ 2 * sdssn):
        i=i+1
        if(x> ssn-sdssn)and(x < ssn+sdssn):
          i=i+2    
          if(x> ssn-0.5*sdssn)and(x < ssn+0.5*sdssn):
            i=i+1
            if(x==ssn):
             i=i+1
    output.append(i)  
    i=0          
data['CTSensing']=output
output=[]
i=0
for x in data.Sound:
    if(x> ss- 2 * sdss)and(x < ss+ 2 * sdss):
        i=i+1
        if(x> ss-sdss)and(x < ss+sdss):
          i=i+2
          if(x> ss-0.5*sdss)and(x < ss+0.5*sdss):
            i=i+1    
            if(x==ss):
             i=i+1
    output.append(i)  
    i=0          
data['CTSound']=output
output=[]
i=0
for x in data.Events:
    if(x> se- 2 * sdse)and(x < se+ 2 * sdse):
        i=i+1
        if(x> se-sdse)and(x < se+sdse):
          i=i+2 
          if(x> se-0.5*sdse)and(x < se+0.5*sdse):
            i=i+1   
            if(x==se):
             i=i+1
    output.append(i)  
    i=0          
data['CTEvents']=output
output=[]
i=0
for x in data.Control:
    if(x> sc- 2 * sdsc)and(x < sc+ 2 * sdsc):
        i=i+1
        if(x> sc-sdsc)and(x < sc+sdsc):
           i=i+2    
           if(x> sc-0.5*sdsc)and(x < sc+0.5*sdsc):
             i=i+1
             if(x==sc):
              i=i+1
    output.append(i)  
    i=0          
data['CTControl']=output
output=[]
i=0
for x in data.Operators:
    if(x> so- 2 * sdso)and(x < so+ 2 * sdso):
        i=i+1
        if(x> so-sdso)and(x < so+sdso):
          i=i+2    
          if(x> so-0.5*sdso)and(x < so+0.5*sdso):
             i=i+1
             if(x==so):
               i=i+1
    output.append(i)  
    i=0          
data['CTOperators']=output
output=[]
i=0
for x in data.Variables:
    if(x> sv- 2 * sdsv)and(x < sv+ 2 * sdsv):
        i=i+1
        if(x> sv-sdsv)and(x < sv+sdsv):
          i=i+2   
          if(x> sv-0.5*sdsv)and(x < sv+0.5*sdsv):
            i=i+1
            if(x==sv):
             i=i+1
    output.append(i)  
    i=0          
data['CTVariables']=output
output=[]
i=0
for x in data.Myblocks:
    if(x> smb- 2 * sdsmb)and(x < smb+ 2 * sdsmb):
        i=i+1
        if(x> smb-sdsmb)and(x < smb+sdsmb):
          i=i+2    
          if(x> smb-0.5*sdsmb)and(x < smb+0.5*sdsmb):
            i=i+1
            if(x==smb):
             i=i+1
    output.append(i)  
    i=0          
data['CTMyblocks']=output
output=[]
i=0
for x in data.TotalCommands:
    if(x> stc- 2 * sdstc)and(x < stc+ 2 * sdstc):
        i=i+1
        if(x> stc-sdstc)and(x < stc+sdstc):
          i=i+2    
          if(x> stc-0.5*sdstc)and(x < stc+0.5*sdstc):
            i=i+1
            if(x==stc):
             i=i+1
    output.append(i)  
    i=0          
data['CTTotalCommands']=output
data.to_csv(r'/CTGame1.csv')

# Game 2
data = pd.read_csv('/game2.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
sdsm=data.Motion.std(axis=0)
se=data.Events.mean(axis=0)
print(se)
sdse=data.Events.std(axis=0)
sc=data.Control.mean(axis=0)
print(sc)
sdsc=data.Control.std(axis=0)
ss=data.Sound.mean(axis=0)
print(ss)
sdss=data.Sound.std(axis=0)
sl=data.Looks.mean(axis=0)
print(sl)
sdsl=data.Looks.std(axis=0)
ssn=data.Sensing.mean(axis=0)
print(ssn)
sdssn=data.Sensing.std(axis=0)
so=data.Operators.mean(axis=0)
print(so)
sdso=data.Operators.std(axis=0)
sv=data.Variables.mean(axis=0)
print(sv)
sdsv=data.Variables.std(axis=0)
smb=data.Myblocks.mean(axis=0)
print(smb)
sdsmb=data.Myblocks.std(axis=0)
stc=data.TotalCommands.mean(axis=0)
sdstc=data.TotalCommands.std(axis=0)
ssp=data.Sprites.mean(axis=0)
sdssp=data.Sprites.std(axis=0)
scs=data.Costumes.mean(axis=0)
sdscs=data.Costumes.std(axis=0)
sb=data.BackDrops.mean(axis=0)
sdsb=data.BackDrops.std(axis=0)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
 name= 'radius=20'

    #opacity=0.8
))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 20], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()

output=[]
i=0
for x in data.Sprites:
    if(x> ssp- 2 * sdssp)and(x < ssp+ 2 * sdssp):
        i=i+1
        if(x> ssp-sdssp)and(x < ssp+sdssp):           
          i=i+2              
          if(x> ssp-0.5*sdssp)and(x < ssp+0.5*sdssp):
            i=i+1
            if(x==ssp):
             i=i+1
    output.append(i)  
    i=0          
data['CTSprites']=output
output=[]
i=0
for x in data.Costumes:
    if(x> scs- 2 * sdscs)and(x < scs+ 2 * sdscs):
        i=i+1
        if(x> scs-sdscs)and(x < scs+sdscs):
          i=i+2 
          if(x> scs-0.5*sdscs)and(x < scs+0.5*sdscs):
           i=i+1       
           if(x==scs):
             i=i+1
    output.append(i)  
    i=0          
data['CTCostumes']=output
output=[]
i=0
for x in data.BackDrops:
    if(x> sb- 2 * sdsb)and(x < sb+ 2 * sdsb):
        i=i+1
        if(x> sb-sdsb)and(x < sb+sdsb):
          i=i+2  
          if(x> sb-0.5*sdsb)and(x < sb+0.5*sdsb):
             i=i+1  
             if(x==sb):
                i=i+1
    output.append(i)  
    i=0          
data['CTBackdrops']=output
output=[]
i=0
for x in data.Motion:
    if(x> sm- 2 * sdsm)and(x < sm+ 2 * sdsm):
        i=i+1
        if(x> sm-sdsm)and(x < sm+sdsm):
          i=i+2 
          if(x> sm-0.5*sdsm)and(x < sm+0.5*sdsm):   
           i=i+1
           if(x==sm):
            i=i+1
    output.append(i)  
    i=0          
data['CTMotion']=output
output=[]
i=0
for x in data.Looks:
    if(x> sl- 2 * sdsl)and(x < sl+ 2 * sdsl):
        i=i+1
        if(x> sl-sdsl)and(x < sl+sdsl):
          i=i+2
          if(x> sl-0.5*sdsl)and(x < sl+0.5*sdsl):    
           i=i+1
           if(x==sl):
            i=i+1
    output.append(i)  
    i=0          
data['CTLooks']=output
output=[]
i=0
for x in data.Sensing:
    if(x> ssn- 2 * sdssn)and(x < ssn+ 2 * sdssn):
        i=i+1
        if(x> ssn-sdssn)and(x < ssn+sdssn):
          i=i+2    
          if(x> ssn-0.5*sdssn)and(x < ssn+0.5*sdssn):
            i=i+1
            if(x==ssn):
             i=i+1
    output.append(i)  
    i=0          
data['CTSensing']=output
output=[]
i=0
for x in data.Sound:
    if(x> ss- 2 * sdss)and(x < ss+ 2 * sdss):
        i=i+1
        if(x> ss-sdss)and(x < ss+sdss):
          i=i+2
          if(x> ss-0.5*sdss)and(x < ss+0.5*sdss):
            i=i+1    
            if(x==ss):
             i=i+1
    output.append(i)  
    i=0          
data['CTSound']=output
output=[]
i=0
for x in data.Events:
    if(x> se- 2 * sdse)and(x < se+ 2 * sdse):
        i=i+1
        if(x> se-sdse)and(x < se+sdse):
          i=i+2 
          if(x> se-0.5*sdse)and(x < se+0.5*sdse):
            i=i+1   
            if(x==se):
             i=i+1
    output.append(i)  
    i=0          
data['CTEvents']=output
output=[]
i=0
for x in data.Control:
    if(x> sc- 2 * sdsc)and(x < sc+ 2 * sdsc):
        i=i+1
        if(x> sc-sdsc)and(x < sc+sdsc):
           i=i+2    
           if(x> sc-0.5*sdsc)and(x < sc+0.5*sdsc):
             i=i+1
             if(x==sc):
              i=i+1
    output.append(i)  
    i=0          
data['CTControl']=output
output=[]
i=0
for x in data.Operators:
    if(x> so- 2 * sdso)and(x < so+ 2 * sdso):
        i=i+1
        if(x> so-sdso)and(x < so+sdso):
          i=i+2    
          if(x> so-0.5*sdso)and(x < so+0.5*sdso):
             i=i+1
             if(x==so):
               i=i+1
    output.append(i)  
    i=0          
data['CTOperators']=output
output=[]
i=0
for x in data.Variables:
    if(x> sv- 2 * sdsv)and(x < sv+ 2 * sdsv):
        i=i+1
        if(x> sv-sdsv)and(x < sv+sdsv):
          i=i+2   
          if(x> sv-0.5*sdsv)and(x < sv+0.5*sdsv):
            i=i+1
            if(x==sv):
             i=i+1
    output.append(i)  
    i=0          
data['CTVariables']=output
output=[]
i=0
for x in data.Myblocks:
    if(x> smb- 2 * sdsmb)and(x < smb+ 2 * sdsmb):
        i=i+1
        if(x> smb-sdsmb)and(x < smb+sdsmb):
          i=i+2    
          if(x> smb-0.5*sdsmb)and(x < smb+0.5*sdsmb):
            i=i+1
            if(x==smb):
             i=i+1
    output.append(i)  
    i=0          
data['CTMyblocks']=output
output=[]
i=0
for x in data.TotalCommands:
    if(x> stc- 2 * sdstc)and(x < stc+ 2 * sdstc):
        i=i+1
        if(x> stc-sdstc)and(x < stc+sdstc):
          i=i+2    
          if(x> stc-0.5*sdstc)and(x < stc+0.5*sdstc):
            i=i+1
            if(x==stc):
             i=i+1
    output.append(i)  
    i=0          
data['CTTotalCommands']=output
data.to_csv(r'/CTGame2.csv')
# Game 3
data = pd.read_csv('/game3.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
sdsm=data.Motion.std(axis=0)
se=data.Events.mean(axis=0)
print(se)
sdse=data.Events.std(axis=0)
sc=data.Control.mean(axis=0)
print(sc)
sdsc=data.Control.std(axis=0)
ss=data.Sound.mean(axis=0)
print(ss)
sdss=data.Sound.std(axis=0)
sl=data.Looks.mean(axis=0)
print(sl)
sdsl=data.Looks.std(axis=0)
ssn=data.Sensing.mean(axis=0)
print(ssn)
sdssn=data.Sensing.std(axis=0)
so=data.Operators.mean(axis=0)
print(so)
sdso=data.Operators.std(axis=0)
sv=data.Variables.mean(axis=0)
print(sv)
sdsv=data.Variables.std(axis=0)
smb=data.Myblocks.mean(axis=0)
print(smb)
sdsmb=data.Myblocks.std(axis=0)
stc=data.TotalCommands.mean(axis=0)
sdstc=data.TotalCommands.std(axis=0)
ssp=data.Sprites.mean(axis=0)
sdssp=data.Sprites.std(axis=0)
scs=data.Costumes.mean(axis=0)
sdscs=data.Costumes.std(axis=0)
sb=data.BackDrops.mean(axis=0)
sdsb=data.BackDrops.std(axis=0)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=15'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 15], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()

output=[]
i=0
for x in data.Sprites:
    if(x> ssp- 2 * sdssp)and(x < ssp+ 2 * sdssp):
        i=i+1
        if(x> ssp-sdssp)and(x < ssp+sdssp):           
          i=i+2              
          if(x> ssp-0.5*sdssp)and(x < ssp+0.5*sdssp):
            i=i+1
            if(x==ssp):
             i=i+1
    output.append(i)  
    i=0          
data['CTSprites']=output
output=[]
i=0
for x in data.Costumes:
    if(x> scs- 2 * sdscs)and(x < scs+ 2 * sdscs):
        i=i+1
        if(x> scs-sdscs)and(x < scs+sdscs):
          i=i+2 
          if(x> scs-0.5*sdscs)and(x < scs+0.5*sdscs):
           i=i+1       
           if(x==scs):
             i=i+1
    output.append(i)  
    i=0          
data['CTCostumes']=output
output=[]
i=0
for x in data.BackDrops:
    if(x> sb- 2 * sdsb)and(x < sb+ 2 * sdsb):
        i=i+1
        if(x> sb-sdsb)and(x < sb+sdsb):
          i=i+2  
          if(x> sb-0.5*sdsb)and(x < sb+0.5*sdsb):
             i=i+1  
             if(x==sb):
                i=i+1
    output.append(i)  
    i=0          
data['CTBackdrops']=output
output=[]
i=0
for x in data.Motion:
    if(x> sm- 2 * sdsm)and(x < sm+ 2 * sdsm):
        i=i+1
        if(x> sm-sdsm)and(x < sm+sdsm):
          i=i+2 
          if(x> sm-0.5*sdsm)and(x < sm+0.5*sdsm):   
           i=i+1
           if(x==sm):
            i=i+1
    output.append(i)  
    i=0          
data['CTMotion']=output
output=[]
i=0
for x in data.Looks:
    if(x> sl- 2 * sdsl)and(x < sl+ 2 * sdsl):
        i=i+1
        if(x> sl-sdsl)and(x < sl+sdsl):
          i=i+2
          if(x> sl-0.5*sdsl)and(x < sl+0.5*sdsl):    
           i=i+1
           if(x==sl):
            i=i+1
    output.append(i)  
    i=0          
data['CTLooks']=output
output=[]
i=0
for x in data.Sensing:
    if(x> ssn- 2 * sdssn)and(x < ssn+ 2 * sdssn):
        i=i+1
        if(x> ssn-sdssn)and(x < ssn+sdssn):
          i=i+2    
          if(x> ssn-0.5*sdssn)and(x < ssn+0.5*sdssn):
            i=i+1
            if(x==ssn):
             i=i+1
    output.append(i)  
    i=0          
data['CTSensing']=output
output=[]
i=0
for x in data.Sound:
    if(x> ss- 2 * sdss)and(x < ss+ 2 * sdss):
        i=i+1
        if(x> ss-sdss)and(x < ss+sdss):
          i=i+2
          if(x> ss-0.5*sdss)and(x < ss+0.5*sdss):
            i=i+1    
            if(x==ss):
             i=i+1
    output.append(i)  
    i=0          
data['CTSound']=output
output=[]
i=0
for x in data.Events:
    if(x> se- 2 * sdse)and(x < se+ 2 * sdse):
        i=i+1
        if(x> se-sdse)and(x < se+sdse):
          i=i+2 
          if(x> se-0.5*sdse)and(x < se+0.5*sdse):
            i=i+1   
            if(x==se):
             i=i+1
    output.append(i)  
    i=0          
data['CTEvents']=output
output=[]
i=0
for x in data.Control:
    if(x> sc- 2 * sdsc)and(x < sc+ 2 * sdsc):
        i=i+1
        if(x> sc-sdsc)and(x < sc+sdsc):
           i=i+2    
           if(x> sc-0.5*sdsc)and(x < sc+0.5*sdsc):
             i=i+1
             if(x==sc):
              i=i+1
    output.append(i)  
    i=0          
data['CTControl']=output
output=[]
i=0
for x in data.Operators:
    if(x> so- 2 * sdso)and(x < so+ 2 * sdso):
        i=i+1
        if(x> so-sdso)and(x < so+sdso):
          i=i+2    
          if(x> so-0.5*sdso)and(x < so+0.5*sdso):
             i=i+1
             if(x==so):
               i=i+1
    output.append(i)  
    i=0          
data['CTOperators']=output
output=[]
i=0
for x in data.Variables:
    if(x> sv- 2 * sdsv)and(x < sv+ 2 * sdsv):
        i=i+1
        if(x> sv-sdsv)and(x < sv+sdsv):
          i=i+2   
          if(x> sv-0.5*sdsv)and(x < sv+0.5*sdsv):
            i=i+1
            if(x==sv):
             i=i+1
    output.append(i)  
    i=0          
data['CTVariables']=output
output=[]
i=0
for x in data.Myblocks:
    if(x> smb- 2 * sdsmb)and(x < smb+ 2 * sdsmb):
        i=i+1
        if(x> smb-sdsmb)and(x < smb+sdsmb):
          i=i+2    
          if(x> smb-0.5*sdsmb)and(x < smb+0.5*sdsmb):
            i=i+1
            if(x==smb):
             i=i+1
    output.append(i)  
    i=0          
data['CTMyblocks']=output
output=[]
i=0
for x in data.TotalCommands:
    if(x> stc- 2 * sdstc)and(x < stc+ 2 * sdstc):
        i=i+1
        if(x> stc-sdstc)and(x < stc+sdstc):
          i=i+2    
          if(x> stc-0.5*sdstc)and(x < stc+0.5*sdstc):
            i=i+1
            if(x==stc):
             i=i+1
    output.append(i)  
    i=0          
data['CTTotalCommands']=output
data.to_csv(r'/CTGame3.csv')
# Game 4
data = pd.read_csv('/game4.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
sdsm=data.Motion.std(axis=0)
se=data.Events.mean(axis=0)
print(se)
sdse=data.Events.std(axis=0)
sc=data.Control.mean(axis=0)
print(sc)
sdsc=data.Control.std(axis=0)
ss=data.Sound.mean(axis=0)
print(ss)
sdss=data.Sound.std(axis=0)
sl=data.Looks.mean(axis=0)
print(sl)
sdsl=data.Looks.std(axis=0)
ssn=data.Sensing.mean(axis=0)
print(ssn)
sdssn=data.Sensing.std(axis=0)
so=data.Operators.mean(axis=0)
print(so)
sdso=data.Operators.std(axis=0)
sv=data.Variables.mean(axis=0)
print(sv)
sdsv=data.Variables.std(axis=0)
smb=data.Myblocks.mean(axis=0)
print(smb)
sdsmb=data.Myblocks.std(axis=0)
stc=data.TotalCommands.mean(axis=0)
sdstc=data.TotalCommands.std(axis=0)
ssp=data.Sprites.mean(axis=0)
sdssp=data.Sprites.std(axis=0)
scs=data.Costumes.mean(axis=0)
sdscs=data.Costumes.std(axis=0)
sb=data.BackDrops.mean(axis=0)
sdsb=data.BackDrops.std(axis=0)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=27'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 27], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()

output=[]
i=0
for x in data.Sprites:
    if(x> ssp- 2 * sdssp)and(x < ssp+ 2 * sdssp):
        i=i+1
        if(x> ssp-sdssp)and(x < ssp+sdssp):           
          i=i+2              
          if(x> ssp-0.5*sdssp)and(x < ssp+0.5*sdssp):
            i=i+1
            if(x==ssp):
             i=i+1
    output.append(i)  
    i=0          
data['CTSprites']=output
output=[]
i=0
for x in data.Costumes:
    if(x> scs- 2 * sdscs)and(x < scs+ 2 * sdscs):
        i=i+1
        if(x> scs-sdscs)and(x < scs+sdscs):
          i=i+2 
          if(x> scs-0.5*sdscs)and(x < scs+0.5*sdscs):
           i=i+1       
           if(x==scs):
             i=i+1
    output.append(i)  
    i=0          
data['CTCostumes']=output
output=[]
i=0
for x in data.BackDrops:
    if(x> sb- 2 * sdsb)and(x < sb+ 2 * sdsb):
        i=i+1
        if(x> sb-sdsb)and(x < sb+sdsb):
          i=i+2  
          if(x> sb-0.5*sdsb)and(x < sb+0.5*sdsb):
             i=i+1  
             if(x==sb):
                i=i+1
    output.append(i)  
    i=0          
data['CTBackdrops']=output
output=[]
i=0
for x in data.Motion:
    if(x> sm- 2 * sdsm)and(x < sm+ 2 * sdsm):
        i=i+1
        if(x> sm-sdsm)and(x < sm+sdsm):
          i=i+2 
          if(x> sm-0.5*sdsm)and(x < sm+0.5*sdsm):   
           i=i+1
           if(x==sm):
            i=i+1
    output.append(i)  
    i=0          
data['CTMotion']=output
output=[]
i=0
for x in data.Looks:
    if(x> sl- 2 * sdsl)and(x < sl+ 2 * sdsl):
        i=i+1
        if(x> sl-sdsl)and(x < sl+sdsl):
          i=i+2
          if(x> sl-0.5*sdsl)and(x < sl+0.5*sdsl):    
           i=i+1
           if(x==sl):
            i=i+1
    output.append(i)  
    i=0          
data['CTLooks']=output
output=[]
i=0
for x in data.Sensing:
    if(x> ssn- 2 * sdssn)and(x < ssn+ 2 * sdssn):
        i=i+1
        if(x> ssn-sdssn)and(x < ssn+sdssn):
          i=i+2    
          if(x> ssn-0.5*sdssn)and(x < ssn+0.5*sdssn):
            i=i+1
            if(x==ssn):
             i=i+1
    output.append(i)  
    i=0          
data['CTSensing']=output
output=[]
i=0
for x in data.Sound:
    if(x> ss- 2 * sdss)and(x < ss+ 2 * sdss):
        i=i+1
        if(x> ss-sdss)and(x < ss+sdss):
          i=i+2
          if(x> ss-0.5*sdss)and(x < ss+0.5*sdss):
            i=i+1    
            if(x==ss):
             i=i+1
    output.append(i)  
    i=0          
data['CTSound']=output
output=[]
i=0
for x in data.Events:
    if(x> se- 2 * sdse)and(x < se+ 2 * sdse):
        i=i+1
        if(x> se-sdse)and(x < se+sdse):
          i=i+2 
          if(x> se-0.5*sdse)and(x < se+0.5*sdse):
            i=i+1   
            if(x==se):
             i=i+1
    output.append(i)  
    i=0          
data['CTEvents']=output
output=[]
i=0
for x in data.Control:
    if(x> sc- 2 * sdsc)and(x < sc+ 2 * sdsc):
        i=i+1
        if(x> sc-sdsc)and(x < sc+sdsc):
           i=i+2    
           if(x> sc-0.5*sdsc)and(x < sc+0.5*sdsc):
             i=i+1
             if(x==sc):
              i=i+1
    output.append(i)  
    i=0          
data['CTControl']=output
output=[]
i=0
for x in data.Operators:
    if(x> so- 2 * sdso)and(x < so+ 2 * sdso):
        i=i+1
        if(x> so-sdso)and(x < so+sdso):
          i=i+2    
          if(x> so-0.5*sdso)and(x < so+0.5*sdso):
             i=i+1
             if(x==so):
               i=i+1
    output.append(i)  
    i=0          
data['CTOperators']=output
output=[]
i=0
for x in data.Variables:
    if(x> sv- 2 * sdsv)and(x < sv+ 2 * sdsv):
        i=i+1
        if(x> sv-sdsv)and(x < sv+sdsv):
          i=i+2   
          if(x> sv-0.5*sdsv)and(x < sv+0.5*sdsv):
            i=i+1
            if(x==sv):
             i=i+1
    output.append(i)  
    i=0          
data['CTVariables']=output
output=[]
i=0
for x in data.Myblocks:
    if(x> smb- 2 * sdsmb)and(x < smb+ 2 * sdsmb):
        i=i+1
        if(x> smb-sdsmb)and(x < smb+sdsmb):
          i=i+2    
          if(x> smb-0.5*sdsmb)and(x < smb+0.5*sdsmb):
            i=i+1
            if(x==smb):
             i=i+1
    output.append(i)  
    i=0          
data['CTMyblocks']=output
output=[]
i=0
for x in data.TotalCommands:
    if(x> stc- 2 * sdstc)and(x < stc+ 2 * sdstc):
        i=i+1
        if(x> stc-sdstc)and(x < stc+sdstc):
          i=i+2    
          if(x> stc-0.5*sdstc)and(x < stc+0.5*sdstc):
            i=i+1
            if(x==stc):
             i=i+1
    output.append(i)  
    i=0          
data['CTTotalCommands']=output
data.to_csv(r'/CTGame4.csv')
# Game 5
data = pd.read_csv('/game5.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
sdsm=data.Motion.std(axis=0)
se=data.Events.mean(axis=0)
print(se)
sdse=data.Events.std(axis=0)
sc=data.Control.mean(axis=0)
print(sc)
sdsc=data.Control.std(axis=0)
ss=data.Sound.mean(axis=0)
print(ss)
sdss=data.Sound.std(axis=0)
sl=data.Looks.mean(axis=0)
print(sl)
sdsl=data.Looks.std(axis=0)
ssn=data.Sensing.mean(axis=0)
print(ssn)
sdssn=data.Sensing.std(axis=0)
so=data.Operators.mean(axis=0)
print(so)
sdso=data.Operators.std(axis=0)
sv=data.Variables.mean(axis=0)
print(sv)
sdsv=data.Variables.std(axis=0)
smb=data.Myblocks.mean(axis=0)
print(smb)
sdsmb=data.Myblocks.std(axis=0)
stc=data.TotalCommands.mean(axis=0)
sdstc=data.TotalCommands.std(axis=0)
ssp=data.Sprites.mean(axis=0)
sdssp=data.Sprites.std(axis=0)
scs=data.Costumes.mean(axis=0)
sdscs=data.Costumes.std(axis=0)
sb=data.BackDrops.mean(axis=0)
sdsb=data.BackDrops.std(axis=0)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=25'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 25], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()

output=[]
i=0
for x in data.Sprites:
    if(x> ssp- 2 * sdssp)and(x < ssp+ 2 * sdssp):
        i=i+1
        if(x> ssp-sdssp)and(x < ssp+sdssp):           
          i=i+2              
          if(x> ssp-0.5*sdssp)and(x < ssp+0.5*sdssp):
            i=i+1
            if(x==ssp):
             i=i+1
    output.append(i)  
    i=0          
data['CTSprites']=output
output=[]
i=0
for x in data.Costumes:
    if(x> scs- 2 * sdscs)and(x < scs+ 2 * sdscs):
        i=i+1
        if(x> scs-sdscs)and(x < scs+sdscs):
          i=i+2 
          if(x> scs-0.5*sdscs)and(x < scs+0.5*sdscs):
           i=i+1       
           if(x==scs):
             i=i+1
    output.append(i)  
    i=0          
data['CTCostumes']=output
output=[]
i=0
for x in data.BackDrops:
    if(x> sb- 2 * sdsb)and(x < sb+ 2 * sdsb):
        i=i+1
        if(x> sb-sdsb)and(x < sb+sdsb):
          i=i+2  
          if(x> sb-0.5*sdsb)and(x < sb+0.5*sdsb):
             i=i+1  
             if(x==sb):
                i=i+1
    output.append(i)  
    i=0          
data['CTBackdrops']=output
output=[]
i=0
for x in data.Motion:
    if(x> sm- 2 * sdsm)and(x < sm+ 2 * sdsm):
        i=i+1
        if(x> sm-sdsm)and(x < sm+sdsm):
          i=i+2 
          if(x> sm-0.5*sdsm)and(x < sm+0.5*sdsm):   
           i=i+1
           if(x==sm):
            i=i+1
    output.append(i)  
    i=0          
data['CTMotion']=output
output=[]
i=0
for x in data.Looks:
    if(x> sl- 2 * sdsl)and(x < sl+ 2 * sdsl):
        i=i+1
        if(x> sl-sdsl)and(x < sl+sdsl):
          i=i+2
          if(x> sl-0.5*sdsl)and(x < sl+0.5*sdsl):    
           i=i+1
           if(x==sl):
            i=i+1
    output.append(i)  
    i=0          
data['CTLooks']=output
output=[]
i=0
for x in data.Sensing:
    if(x> ssn- 2 * sdssn)and(x < ssn+ 2 * sdssn):
        i=i+1
        if(x> ssn-sdssn)and(x < ssn+sdssn):
          i=i+2    
          if(x> ssn-0.5*sdssn)and(x < ssn+0.5*sdssn):
            i=i+1
            if(x==ssn):
             i=i+1
    output.append(i)  
    i=0          
data['CTSensing']=output
output=[]
i=0
for x in data.Sound:
    if(x> ss- 2 * sdss)and(x < ss+ 2 * sdss):
        i=i+1
        if(x> ss-sdss)and(x < ss+sdss):
          i=i+2
          if(x> ss-0.5*sdss)and(x < ss+0.5*sdss):
            i=i+1    
            if(x==ss):
             i=i+1
    output.append(i)  
    i=0          
data['CTSound']=output
output=[]
i=0
for x in data.Events:
    if(x> se- 2 * sdse)and(x < se+ 2 * sdse):
        i=i+1
        if(x> se-sdse)and(x < se+sdse):
          i=i+2 
          if(x> se-0.5*sdse)and(x < se+0.5*sdse):
            i=i+1   
            if(x==se):
             i=i+1
    output.append(i)  
    i=0          
data['CTEvents']=output
output=[]
i=0
for x in data.Control:
    if(x> sc- 2 * sdsc)and(x < sc+ 2 * sdsc):
        i=i+1
        if(x> sc-sdsc)and(x < sc+sdsc):
           i=i+2    
           if(x> sc-0.5*sdsc)and(x < sc+0.5*sdsc):
             i=i+1
             if(x==sc):
              i=i+1
    output.append(i)  
    i=0          
data['CTControl']=output
output=[]
i=0
for x in data.Operators:
    if(x> so- 2 * sdso)and(x < so+ 2 * sdso):
        i=i+1
        if(x> so-sdso)and(x < so+sdso):
          i=i+2    
          if(x> so-0.5*sdso)and(x < so+0.5*sdso):
             i=i+1
             if(x==so):
               i=i+1
    output.append(i)  
    i=0          
data['CTOperators']=output
output=[]
i=0
for x in data.Variables:
    if(x> sv- 2 * sdsv)and(x < sv+ 2 * sdsv):
        i=i+1
        if(x> sv-sdsv)and(x < sv+sdsv):
          i=i+2   
          if(x> sv-0.5*sdsv)and(x < sv+0.5*sdsv):
            i=i+1
            if(x==sv):
             i=i+1
    output.append(i)  
    i=0          
data['CTVariables']=output
output=[]
i=0
for x in data.Myblocks:
    if(x> smb- 2 * sdsmb)and(x < smb+ 2 * sdsmb):
        i=i+1
        if(x> smb-sdsmb)and(x < smb+sdsmb):
          i=i+2    
          if(x> smb-0.5*sdsmb)and(x < smb+0.5*sdsmb):
            i=i+1
            if(x==smb):
             i=i+1
    output.append(i)  
    i=0          
data['CTMyblocks']=output
output=[]
i=0
for x in data.TotalCommands:
    if(x> stc- 2 * sdstc)and(x < stc+ 2 * sdstc):
        i=i+1
        if(x> stc-sdstc)and(x < stc+sdstc):
          i=i+2    
          if(x> stc-0.5*sdstc)and(x < stc+0.5*sdstc):
            i=i+1
            if(x==stc):
             i=i+1
    output.append(i)  
    i=0          
data['CTTotalCommands']=output
data.to_csv(r'/CTGame5.csv')
# Game 6
data = pd.read_csv('/game6.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
sdsm=data.Motion.std(axis=0)
se=data.Events.mean(axis=0)
print(se)
sdse=data.Events.std(axis=0)
sc=data.Control.mean(axis=0)
print(sc)
sdsc=data.Control.std(axis=0)
ss=data.Sound.mean(axis=0)
print(ss)
sdss=data.Sound.std(axis=0)
sl=data.Looks.mean(axis=0)
print(sl)
sdsl=data.Looks.std(axis=0)
ssn=data.Sensing.mean(axis=0)
print(ssn)
sdssn=data.Sensing.std(axis=0)
so=data.Operators.mean(axis=0)
print(so)
sdso=data.Operators.std(axis=0)
sv=data.Variables.mean(axis=0)
print(sv)
sdsv=data.Variables.std(axis=0)
smb=data.Myblocks.mean(axis=0)
print(smb)
sdsmb=data.Myblocks.std(axis=0)
stc=data.TotalCommands.mean(axis=0)
sdstc=data.TotalCommands.std(axis=0)
ssp=data.Sprites.mean(axis=0)
sdssp=data.Sprites.std(axis=0)
scs=data.Costumes.mean(axis=0)
sdscs=data.Costumes.std(axis=0)
sb=data.BackDrops.mean(axis=0)
sdsb=data.BackDrops.std(axis=0)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=50'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 50], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()

output=[]
i=0
for x in data.Sprites:
    if(x> ssp- 2 * sdssp)and(x < ssp+ 2 * sdssp):
        i=i+1
        if(x> ssp-sdssp)and(x < ssp+sdssp):           
          i=i+2              
          if(x> ssp-0.5*sdssp)and(x < ssp+0.5*sdssp):
            i=i+1
            if(x==ssp):
             i=i+1
    output.append(i)  
    i=0          
data['CTSprites']=output
output=[]
i=0
for x in data.Costumes:
    if(x> scs- 2 * sdscs)and(x < scs+ 2 * sdscs):
        i=i+1
        if(x> scs-sdscs)and(x < scs+sdscs):
          i=i+2 
          if(x> scs-0.5*sdscs)and(x < scs+0.5*sdscs):
           i=i+1       
           if(x==scs):
             i=i+1
    output.append(i)  
    i=0          
data['CTCostumes']=output
output=[]
i=0
for x in data.BackDrops:
    if(x> sb- 2 * sdsb)and(x < sb+ 2 * sdsb):
        i=i+1
        if(x> sb-sdsb)and(x < sb+sdsb):
          i=i+2  
          if(x> sb-0.5*sdsb)and(x < sb+0.5*sdsb):
             i=i+1  
             if(x==sb):
                i=i+1
    output.append(i)  
    i=0          
data['CTBackdrops']=output
output=[]
i=0
for x in data.Motion:
    if(x> sm- 2 * sdsm)and(x < sm+ 2 * sdsm):
        i=i+1
        if(x> sm-sdsm)and(x < sm+sdsm):
          i=i+2 
          if(x> sm-0.5*sdsm)and(x < sm+0.5*sdsm):   
           i=i+1
           if(x==sm):
            i=i+1
    output.append(i)  
    i=0          
data['CTMotion']=output
output=[]
i=0
for x in data.Looks:
    if(x> sl- 2 * sdsl)and(x < sl+ 2 * sdsl):
        i=i+1
        if(x> sl-sdsl)and(x < sl+sdsl):
          i=i+2
          if(x> sl-0.5*sdsl)and(x < sl+0.5*sdsl):    
           i=i+1
           if(x==sl):
            i=i+1
    output.append(i)  
    i=0          
data['CTLooks']=output
output=[]
i=0
for x in data.Sensing:
    if(x> ssn- 2 * sdssn)and(x < ssn+ 2 * sdssn):
        i=i+1
        if(x> ssn-sdssn)and(x < ssn+sdssn):
          i=i+2    
          if(x> ssn-0.5*sdssn)and(x < ssn+0.5*sdssn):
            i=i+1
            if(x==ssn):
             i=i+1
    output.append(i)  
    i=0          
data['CTSensing']=output
output=[]
i=0
for x in data.Sound:
    if(x> ss- 2 * sdss)and(x < ss+ 2 * sdss):
        i=i+1
        if(x> ss-sdss)and(x < ss+sdss):
          i=i+2
          if(x> ss-0.5*sdss)and(x < ss+0.5*sdss):
            i=i+1    
            if(x==ss):
             i=i+1
    output.append(i)  
    i=0          
data['CTSound']=output
output=[]
i=0
for x in data.Events:
    if(x> se- 2 * sdse)and(x < se+ 2 * sdse):
        i=i+1
        if(x> se-sdse)and(x < se+sdse):
          i=i+2 
          if(x> se-0.5*sdse)and(x < se+0.5*sdse):
            i=i+1   
            if(x==se):
             i=i+1
    output.append(i)  
    i=0          
data['CTEvents']=output
output=[]
i=0
for x in data.Control:
    if(x> sc- 2 * sdsc)and(x < sc+ 2 * sdsc):
        i=i+1
        if(x> sc-sdsc)and(x < sc+sdsc):
           i=i+2    
           if(x> sc-0.5*sdsc)and(x < sc+0.5*sdsc):
             i=i+1
             if(x==sc):
              i=i+1
    output.append(i)  
    i=0          
data['CTControl']=output
output=[]
i=0
for x in data.Operators:
    if(x> so- 2 * sdso)and(x < so+ 2 * sdso):
        i=i+1
        if(x> so-sdso)and(x < so+sdso):
          i=i+2    
          if(x> so-0.5*sdso)and(x < so+0.5*sdso):
             i=i+1
             if(x==so):
               i=i+1
    output.append(i)  
    i=0          
data['CTOperators']=output
output=[]
i=0
for x in data.Variables:
    if(x> sv- 2 * sdsv)and(x < sv+ 2 * sdsv):
        i=i+1
        if(x> sv-sdsv)and(x < sv+sdsv):
          i=i+2   
          if(x> sv-0.5*sdsv)and(x < sv+0.5*sdsv):
            i=i+1
            if(x==sv):
             i=i+1
    output.append(i)  
    i=0          
data['CTVariables']=output
output=[]
i=0
for x in data.Myblocks:
    if(x> smb- 2 * sdsmb)and(x < smb+ 2 * sdsmb):
        i=i+1
        if(x> smb-sdsmb)and(x < smb+sdsmb):
          i=i+2    
          if(x> smb-0.5*sdsmb)and(x < smb+0.5*sdsmb):
            i=i+1
            if(x==smb):
             i=i+1
    output.append(i)  
    i=0          
data['CTMyblocks']=output
output=[]
i=0
for x in data.TotalCommands:
    if(x> stc- 2 * sdstc)and(x < stc+ 2 * sdstc):
        i=i+1
        if(x> stc-sdstc)and(x < stc+sdstc):
          i=i+2    
          if(x> stc-0.5*sdstc)and(x < stc+0.5*sdstc):
            i=i+1
            if(x==stc):
             i=i+1
    output.append(i)  
    i=0          
data['CTTotalCommands']=output
data.to_csv(r'/CTGame6.csv')
# Game 7
data = pd.read_csv('/game7.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
sdsm=data.Motion.std(axis=0)
se=data.Events.mean(axis=0)
print(se)
sdse=data.Events.std(axis=0)
sc=data.Control.mean(axis=0)
print(sc)
sdsc=data.Control.std(axis=0)
ss=data.Sound.mean(axis=0)
print(ss)
sdss=data.Sound.std(axis=0)
sl=data.Looks.mean(axis=0)
print(sl)
sdsl=data.Looks.std(axis=0)
ssn=data.Sensing.mean(axis=0)
print(ssn)
sdssn=data.Sensing.std(axis=0)
so=data.Operators.mean(axis=0)
print(so)
sdso=data.Operators.std(axis=0)
sv=data.Variables.mean(axis=0)
print(sv)
sdsv=data.Variables.std(axis=0)
smb=data.Myblocks.mean(axis=0)
print(smb)
sdsmb=data.Myblocks.std(axis=0)
stc=data.TotalCommands.mean(axis=0)
sdstc=data.TotalCommands.std(axis=0)
ssp=data.Sprites.mean(axis=0)
sdssp=data.Sprites.std(axis=0)
scs=data.Costumes.mean(axis=0)
sdscs=data.Costumes.std(axis=0)
sb=data.BackDrops.mean(axis=0)
sdsb=data.BackDrops.std(axis=0)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=150'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 40], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()

output=[]
i=0
for x in data.Sprites:
    if(x> ssp- 2 * sdssp)and(x < ssp+ 2 * sdssp):
        i=i+1
        if(x> ssp-sdssp)and(x < ssp+sdssp):           
          i=i+2              
          if(x> ssp-0.5*sdssp)and(x < ssp+0.5*sdssp):
            i=i+1
            if(x==ssp):
             i=i+1
    output.append(i)  
    i=0          
data['CTSprites']=output
output=[]
i=0
for x in data.Costumes:
    if(x> scs- 2 * sdscs)and(x < scs+ 2 * sdscs):
        i=i+1
        if(x> scs-sdscs)and(x < scs+sdscs):
          i=i+2 
          if(x> scs-0.5*sdscs)and(x < scs+0.5*sdscs):
           i=i+1       
           if(x==scs):
             i=i+1
    output.append(i)  
    i=0          
data['CTCostumes']=output
output=[]
i=0
for x in data.BackDrops:
    if(x> sb- 2 * sdsb)and(x < sb+ 2 * sdsb):
        i=i+1
        if(x> sb-sdsb)and(x < sb+sdsb):
          i=i+2  
          if(x> sb-0.5*sdsb)and(x < sb+0.5*sdsb):
             i=i+1  
             if(x==sb):
                i=i+1
    output.append(i)  
    i=0          
data['CTBackdrops']=output
output=[]
i=0
for x in data.Motion:
    if(x> sm- 2 * sdsm)and(x < sm+ 2 * sdsm):
        i=i+1
        if(x> sm-sdsm)and(x < sm+sdsm):
          i=i+2 
          if(x> sm-0.5*sdsm)and(x < sm+0.5*sdsm):   
           i=i+1
           if(x==sm):
            i=i+1
    output.append(i)  
    i=0          
data['CTMotion']=output
output=[]
i=0
for x in data.Looks:
    if(x> sl- 2 * sdsl)and(x < sl+ 2 * sdsl):
        i=i+1
        if(x> sl-sdsl)and(x < sl+sdsl):
          i=i+2
          if(x> sl-0.5*sdsl)and(x < sl+0.5*sdsl):    
           i=i+1
           if(x==sl):
            i=i+1
    output.append(i)  
    i=0          
data['CTLooks']=output
output=[]
i=0
for x in data.Sensing:
    if(x> ssn- 2 * sdssn)and(x < ssn+ 2 * sdssn):
        i=i+1
        if(x> ssn-sdssn)and(x < ssn+sdssn):
          i=i+2    
          if(x> ssn-0.5*sdssn)and(x < ssn+0.5*sdssn):
            i=i+1
            if(x==ssn):
             i=i+1
    output.append(i)  
    i=0          
data['CTSensing']=output
output=[]
i=0
for x in data.Sound:
    if(x> ss- 2 * sdss)and(x < ss+ 2 * sdss):
        i=i+1
        if(x> ss-sdss)and(x < ss+sdss):
          i=i+2
          if(x> ss-0.5*sdss)and(x < ss+0.5*sdss):
            i=i+1    
            if(x==ss):
             i=i+1
    output.append(i)  
    i=0          
data['CTSound']=output
output=[]
i=0
for x in data.Events:
    if(x> se- 2 * sdse)and(x < se+ 2 * sdse):
        i=i+1
        if(x> se-sdse)and(x < se+sdse):
          i=i+2 
          if(x> se-0.5*sdse)and(x < se+0.5*sdse):
            i=i+1   
            if(x==se):
             i=i+1
    output.append(i)  
    i=0          
data['CTEvents']=output
output=[]
i=0
for x in data.Control:
    if(x> sc- 2 * sdsc)and(x < sc+ 2 * sdsc):
        i=i+1
        if(x> sc-sdsc)and(x < sc+sdsc):
           i=i+2    
           if(x> sc-0.5*sdsc)and(x < sc+0.5*sdsc):
             i=i+1
             if(x==sc):
              i=i+1
    output.append(i)  
    i=0          
data['CTControl']=output
output=[]
i=0
for x in data.Operators:
    if(x> so- 2 * sdso)and(x < so+ 2 * sdso):
        i=i+1
        if(x> so-sdso)and(x < so+sdso):
          i=i+2    
          if(x> so-0.5*sdso)and(x < so+0.5*sdso):
             i=i+1
             if(x==so):
               i=i+1
    output.append(i)  
    i=0          
data['CTOperators']=output
output=[]
i=0
for x in data.Variables:
    if(x> sv- 2 * sdsv)and(x < sv+ 2 * sdsv):
        i=i+1
        if(x> sv-sdsv)and(x < sv+sdsv):
          i=i+2   
          if(x> sv-0.5*sdsv)and(x < sv+0.5*sdsv):
            i=i+1
            if(x==sv):
             i=i+1
    output.append(i)  
    i=0          
data['CTVariables']=output
output=[]
i=0
for x in data.Myblocks:
    if(x> smb- 2 * sdsmb)and(x < smb+ 2 * sdsmb):
        i=i+1
        if(x> smb-sdsmb)and(x < smb+sdsmb):
          i=i+2    
          if(x> smb-0.5*sdsmb)and(x < smb+0.5*sdsmb):
            i=i+1
            if(x==smb):
             i=i+1
    output.append(i)  
    i=0          
data['CTMyblocks']=output
output=[]
i=0
for x in data.TotalCommands:
    if(x> stc- 2 * sdstc)and(x < stc+ 2 * sdstc):
        i=i+1
        if(x> stc-sdstc)and(x < stc+sdstc):
          i=i+2    
          if(x> stc-0.5*sdstc)and(x < stc+0.5*sdstc):
            i=i+1
            if(x==stc):
             i=i+1
    output.append(i)  
    i=0          
data['CTTotalCommands']=output
data.to_csv(r'/CTGame7.csv')
# Game 8
data = pd.read_csv('/game8.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
sdsm=data.Motion.std(axis=0)
se=data.Events.mean(axis=0)
print(se)
sdse=data.Events.std(axis=0)
sc=data.Control.mean(axis=0)
print(sc)
sdsc=data.Control.std(axis=0)
ss=data.Sound.mean(axis=0)
print(ss)
sdss=data.Sound.std(axis=0)
sl=data.Looks.mean(axis=0)
print(sl)
sdsl=data.Looks.std(axis=0)
ssn=data.Sensing.mean(axis=0)
print(ssn)
sdssn=data.Sensing.std(axis=0)
so=data.Operators.mean(axis=0)
print(so)
sdso=data.Operators.std(axis=0)
sv=data.Variables.mean(axis=0)
print(sv)
sdsv=data.Variables.std(axis=0)
smb=data.Myblocks.mean(axis=0)
print(smb)
sdsmb=data.Myblocks.std(axis=0)
stc=data.TotalCommands.mean(axis=0)
sdstc=data.TotalCommands.std(axis=0)
ssp=data.Sprites.mean(axis=0)
sdssp=data.Sprites.std(axis=0)
scs=data.Costumes.mean(axis=0)
sdscs=data.Costumes.std(axis=0)
sb=data.BackDrops.mean(axis=0)
sdsb=data.BackDrops.std(axis=0)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=60'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 60], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()

output=[]
i=0
for x in data.Sprites:
    if(x> ssp- 2 * sdssp)and(x < ssp+ 2 * sdssp):
        i=i+1
        if(x> ssp-sdssp)and(x < ssp+sdssp):           
          i=i+2              
          if(x> ssp-0.5*sdssp)and(x < ssp+0.5*sdssp):
            i=i+1
            if(x==ssp):
             i=i+1
    output.append(i)  
    i=0          
data['CTSprites']=output
output=[]
i=0
for x in data.Costumes:
    if(x> scs- 2 * sdscs)and(x < scs+ 2 * sdscs):
        i=i+1
        if(x> scs-sdscs)and(x < scs+sdscs):
          i=i+2 
          if(x> scs-0.5*sdscs)and(x < scs+0.5*sdscs):
           i=i+1       
           if(x==scs):
             i=i+1
    output.append(i)  
    i=0          
data['CTCostumes']=output
output=[]
i=0
for x in data.BackDrops:
    if(x> sb- 2 * sdsb)and(x < sb+ 2 * sdsb):
        i=i+1
        if(x> sb-sdsb)and(x < sb+sdsb):
          i=i+2  
          if(x> sb-0.5*sdsb)and(x < sb+0.5*sdsb):
             i=i+1  
             if(x==sb):
                i=i+1
    output.append(i)  
    i=0          
data['CTBackdrops']=output
output=[]
i=0
for x in data.Motion:
    if(x> sm- 2 * sdsm)and(x < sm+ 2 * sdsm):
        i=i+1
        if(x> sm-sdsm)and(x < sm+sdsm):
          i=i+2 
          if(x> sm-0.5*sdsm)and(x < sm+0.5*sdsm):   
           i=i+1
           if(x==sm):
            i=i+1
    output.append(i)  
    i=0          
data['CTMotion']=output
output=[]
i=0
for x in data.Looks:
    if(x> sl- 2 * sdsl)and(x < sl+ 2 * sdsl):
        i=i+1
        if(x> sl-sdsl)and(x < sl+sdsl):
          i=i+2
          if(x> sl-0.5*sdsl)and(x < sl+0.5*sdsl):    
           i=i+1
           if(x==sl):
            i=i+1
    output.append(i)  
    i=0          
data['CTLooks']=output
output=[]
i=0
for x in data.Sensing:
    if(x> ssn- 2 * sdssn)and(x < ssn+ 2 * sdssn):
        i=i+1
        if(x> ssn-sdssn)and(x < ssn+sdssn):
          i=i+2    
          if(x> ssn-0.5*sdssn)and(x < ssn+0.5*sdssn):
            i=i+1
            if(x==ssn):
             i=i+1
    output.append(i)  
    i=0          
data['CTSensing']=output
output=[]
i=0
for x in data.Sound:
    if(x> ss- 2 * sdss)and(x < ss+ 2 * sdss):
        i=i+1
        if(x> ss-sdss)and(x < ss+sdss):
          i=i+2
          if(x> ss-0.5*sdss)and(x < ss+0.5*sdss):
            i=i+1    
            if(x==ss):
             i=i+1
    output.append(i)  
    i=0          
data['CTSound']=output
output=[]
i=0
for x in data.Events:
    if(x> se- 2 * sdse)and(x < se+ 2 * sdse):
        i=i+1
        if(x> se-sdse)and(x < se+sdse):
          i=i+2 
          if(x> se-0.5*sdse)and(x < se+0.5*sdse):
            i=i+1   
            if(x==se):
             i=i+1
    output.append(i)  
    i=0          
data['CTEvents']=output
output=[]
i=0
for x in data.Control:
    if(x> sc- 2 * sdsc)and(x < sc+ 2 * sdsc):
        i=i+1
        if(x> sc-sdsc)and(x < sc+sdsc):
           i=i+2    
           if(x> sc-0.5*sdsc)and(x < sc+0.5*sdsc):
             i=i+1
             if(x==sc):
              i=i+1
    output.append(i)  
    i=0          
data['CTControl']=output
output=[]
i=0
for x in data.Operators:
    if(x> so- 2 * sdso)and(x < so+ 2 * sdso):
        i=i+1
        if(x> so-sdso)and(x < so+sdso):
          i=i+2    
          if(x> so-0.5*sdso)and(x < so+0.5*sdso):
             i=i+1
             if(x==so):
               i=i+1
    output.append(i)  
    i=0          
data['CTOperators']=output
output=[]
i=0
for x in data.Variables:
    if(x> sv- 2 * sdsv)and(x < sv+ 2 * sdsv):
        i=i+1
        if(x> sv-sdsv)and(x < sv+sdsv):
          i=i+2   
          if(x> sv-0.5*sdsv)and(x < sv+0.5*sdsv):
            i=i+1
            if(x==sv):
             i=i+1
    output.append(i)  
    i=0          
data['CTVariables']=output
output=[]
i=0
for x in data.Myblocks:
    if(x> smb- 2 * sdsmb)and(x < smb+ 2 * sdsmb):
        i=i+1
        if(x> smb-sdsmb)and(x < smb+sdsmb):
          i=i+2    
          if(x> smb-0.5*sdsmb)and(x < smb+0.5*sdsmb):
            i=i+1
            if(x==smb):
             i=i+1
    output.append(i)  
    i=0          
data['CTMyblocks']=output
output=[]
i=0
for x in data.TotalCommands:
    if(x> stc- 2 * sdstc)and(x < stc+ 2 * sdstc):
        i=i+1
        if(x> stc-sdstc)and(x < stc+sdstc):
          i=i+2    
          if(x> stc-0.5*sdstc)and(x < stc+0.5*sdstc):
            i=i+1
            if(x==stc):
             i=i+1
    output.append(i)  
    i=0          
data['CTTotalCommands']=output
data.to_csv(r'/CTGame8.csv')
# Game 9
data = pd.read_csv('/game9.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
sdsm=data.Motion.std(axis=0)
se=data.Events.mean(axis=0)
print(se)
sdse=data.Events.std(axis=0)
sc=data.Control.mean(axis=0)
print(sc)
sdsc=data.Control.std(axis=0)
ss=data.Sound.mean(axis=0)
print(ss)
sdss=data.Sound.std(axis=0)
sl=data.Looks.mean(axis=0)
print(sl)
sdsl=data.Looks.std(axis=0)
ssn=data.Sensing.mean(axis=0)
print(ssn)
sdssn=data.Sensing.std(axis=0)
so=data.Operators.mean(axis=0)
print(so)
sdso=data.Operators.std(axis=0)
sv=data.Variables.mean(axis=0)
print(sv)
sdsv=data.Variables.std(axis=0)
smb=data.Myblocks.mean(axis=0)
print(smb)
sdsmb=data.Myblocks.std(axis=0)
stc=data.TotalCommands.mean(axis=0)
sdstc=data.TotalCommands.std(axis=0)
ssp=data.Sprites.mean(axis=0)
sdssp=data.Sprites.std(axis=0)
scs=data.Costumes.mean(axis=0)
sdscs=data.Costumes.std(axis=0)
sb=data.BackDrops.mean(axis=0)
sdsb=data.BackDrops.std(axis=0)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=10'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 10], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()

output=[]
i=0
for x in data.Sprites:
    if(x> ssp- 2 * sdssp)and(x < ssp+ 2 * sdssp):
        i=i+1
        if(x> ssp-sdssp)and(x < ssp+sdssp):           
          i=i+2              
          if(x> ssp-0.5*sdssp)and(x < ssp+0.5*sdssp):
            i=i+1
            if(x==ssp):
             i=i+1
    output.append(i)  
    i=0          
data['CTSprites']=output
output=[]
i=0
for x in data.Costumes:
    if(x> scs- 2 * sdscs)and(x < scs+ 2 * sdscs):
        i=i+1
        if(x> scs-sdscs)and(x < scs+sdscs):
          i=i+2 
          if(x> scs-0.5*sdscs)and(x < scs+0.5*sdscs):
           i=i+1       
           if(x==scs):
             i=i+1
    output.append(i)  
    i=0          
data['CTCostumes']=output
output=[]
i=0
for x in data.BackDrops:
    if(x> sb- 2 * sdsb)and(x < sb+ 2 * sdsb):
        i=i+1
        if(x> sb-sdsb)and(x < sb+sdsb):
          i=i+2  
          if(x> sb-0.5*sdsb)and(x < sb+0.5*sdsb):
             i=i+1  
             if(x==sb):
                i=i+1
    output.append(i)  
    i=0          
data['CTBackdrops']=output
output=[]
i=0
for x in data.Motion:
    if(x> sm- 2 * sdsm)and(x < sm+ 2 * sdsm):
        i=i+1
        if(x> sm-sdsm)and(x < sm+sdsm):
          i=i+2 
          if(x> sm-0.5*sdsm)and(x < sm+0.5*sdsm):   
           i=i+1
           if(x==sm):
            i=i+1
    output.append(i)  
    i=0          
data['CTMotion']=output
output=[]
i=0
for x in data.Looks:
    if(x> sl- 2 * sdsl)and(x < sl+ 2 * sdsl):
        i=i+1
        if(x> sl-sdsl)and(x < sl+sdsl):
          i=i+2
          if(x> sl-0.5*sdsl)and(x < sl+0.5*sdsl):    
           i=i+1
           if(x==sl):
            i=i+1
    output.append(i)  
    i=0          
data['CTLooks']=output
output=[]
i=0
for x in data.Sensing:
    if(x> ssn- 2 * sdssn)and(x < ssn+ 2 * sdssn):
        i=i+1
        if(x> ssn-sdssn)and(x < ssn+sdssn):
          i=i+2    
          if(x> ssn-0.5*sdssn)and(x < ssn+0.5*sdssn):
            i=i+1
            if(x==ssn):
             i=i+1
    output.append(i)  
    i=0          
data['CTSensing']=output
output=[]
i=0
for x in data.Sound:
    if(x> ss- 2 * sdss)and(x < ss+ 2 * sdss):
        i=i+1
        if(x> ss-sdss)and(x < ss+sdss):
          i=i+2
          if(x> ss-0.5*sdss)and(x < ss+0.5*sdss):
            i=i+1    
            if(x==ss):
             i=i+1
    output.append(i)  
    i=0          
data['CTSound']=output
output=[]
i=0
for x in data.Events:
    if(x> se- 2 * sdse)and(x < se+ 2 * sdse):
        i=i+1
        if(x> se-sdse)and(x < se+sdse):
          i=i+2 
          if(x> se-0.5*sdse)and(x < se+0.5*sdse):
            i=i+1   
            if(x==se):
             i=i+1
    output.append(i)  
    i=0          
data['CTEvents']=output
output=[]
i=0
for x in data.Control:
    if(x> sc- 2 * sdsc)and(x < sc+ 2 * sdsc):
        i=i+1
        if(x> sc-sdsc)and(x < sc+sdsc):
           i=i+2    
           if(x> sc-0.5*sdsc)and(x < sc+0.5*sdsc):
             i=i+1
             if(x==sc):
              i=i+1
    output.append(i)  
    i=0          
data['CTControl']=output
output=[]
i=0
for x in data.Operators:
    if(x> so- 2 * sdso)and(x < so+ 2 * sdso):
        i=i+1
        if(x> so-sdso)and(x < so+sdso):
          i=i+2    
          if(x> so-0.5*sdso)and(x < so+0.5*sdso):
             i=i+1
             if(x==so):
               i=i+1
    output.append(i)  
    i=0          
data['CTOperators']=output
output=[]
i=0
for x in data.Variables:
    if(x> sv- 2 * sdsv)and(x < sv+ 2 * sdsv):
        i=i+1
        if(x> sv-sdsv)and(x < sv+sdsv):
          i=i+2   
          if(x> sv-0.5*sdsv)and(x < sv+0.5*sdsv):
            i=i+1
            if(x==sv):
             i=i+1
    output.append(i)  
    i=0          
data['CTVariables']=output
output=[]
i=0
for x in data.Myblocks:
    if(x> smb- 2 * sdsmb)and(x < smb+ 2 * sdsmb):
        i=i+1
        if(x> smb-sdsmb)and(x < smb+sdsmb):
          i=i+2    
          if(x> smb-0.5*sdsmb)and(x < smb+0.5*sdsmb):
            i=i+1
            if(x==smb):
             i=i+1
    output.append(i)  
    i=0          
data['CTMyblocks']=output
output=[]
i=0
for x in data.TotalCommands:
    if(x> stc- 2 * sdstc)and(x < stc+ 2 * sdstc):
        i=i+1
        if(x> stc-sdstc)and(x < stc+sdstc):
          i=i+2    
          if(x> stc-0.5*sdstc)and(x < stc+0.5*sdstc):
            i=i+1
            if(x==stc):
             i=i+1
    output.append(i)  
    i=0          
data['CTTotalCommands']=output
data.to_csv(r'/CTGame9.csv')
# Game 10
data = pd.read_csv('/game10.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
sdsm=data.Motion.std(axis=0)
se=data.Events.mean(axis=0)
print(se)
sdse=data.Events.std(axis=0)
sc=data.Control.mean(axis=0)
print(sc)
sdsc=data.Control.std(axis=0)
ss=data.Sound.mean(axis=0)
print(ss)
sdss=data.Sound.std(axis=0)
sl=data.Looks.mean(axis=0)
print(sl)
sdsl=data.Looks.std(axis=0)
ssn=data.Sensing.mean(axis=0)
print(ssn)
sdssn=data.Sensing.std(axis=0)
so=data.Operators.mean(axis=0)
print(so)
sdso=data.Operators.std(axis=0)
sv=data.Variables.mean(axis=0)
print(sv)
sdsv=data.Variables.std(axis=0)
smb=data.Myblocks.mean(axis=0)
print(smb)
sdsmb=data.Myblocks.std(axis=0)
stc=data.TotalCommands.mean(axis=0)
sdstc=data.TotalCommands.std(axis=0)
ssp=data.Sprites.mean(axis=0)
sdssp=data.Sprites.std(axis=0)
scs=data.Costumes.mean(axis=0)
sdscs=data.Costumes.std(axis=0)
sb=data.BackDrops.mean(axis=0)
sdsb=data.BackDrops.std(axis=0)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=150'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()

output=[]
i=0
for x in data.Sprites:
    if(x> ssp- 2 * sdssp)and(x < ssp+ 2 * sdssp):
        i=i+1
        if(x> ssp-sdssp)and(x < ssp+sdssp):           
          i=i+2              
          if(x> ssp-0.5*sdssp)and(x < ssp+0.5*sdssp):
            i=i+1
            if(x==ssp):
             i=i+1
    output.append(i)  
    i=0          
data['CTSprites']=output
output=[]
i=0
for x in data.Costumes:
    if(x> scs- 2 * sdscs)and(x < scs+ 2 * sdscs):
        i=i+1
        if(x> scs-sdscs)and(x < scs+sdscs):
          i=i+2 
          if(x> scs-0.5*sdscs)and(x < scs+0.5*sdscs):
           i=i+1       
           if(x==scs):
             i=i+1
    output.append(i)  
    i=0          
data['CTCostumes']=output
output=[]
i=0
for x in data.BackDrops:
    if(x> sb- 2 * sdsb)and(x < sb+ 2 * sdsb):
        i=i+1
        if(x> sb-sdsb)and(x < sb+sdsb):
          i=i+2  
          if(x> sb-0.5*sdsb)and(x < sb+0.5*sdsb):
             i=i+1  
             if(x==sb):
                i=i+1
    output.append(i)  
    i=0          
data['CTBackdrops']=output
output=[]
i=0
for x in data.Motion:
    if(x> sm- 2 * sdsm)and(x < sm+ 2 * sdsm):
        i=i+1
        if(x> sm-sdsm)and(x < sm+sdsm):
          i=i+2 
          if(x> sm-0.5*sdsm)and(x < sm+0.5*sdsm):   
           i=i+1
           if(x==sm):
            i=i+1
    output.append(i)  
    i=0          
data['CTMotion']=output
output=[]
i=0
for x in data.Looks:
    if(x> sl- 2 * sdsl)and(x < sl+ 2 * sdsl):
        i=i+1
        if(x> sl-sdsl)and(x < sl+sdsl):
          i=i+2
          if(x> sl-0.5*sdsl)and(x < sl+0.5*sdsl):    
           i=i+1
           if(x==sl):
            i=i+1
    output.append(i)  
    i=0          
data['CTLooks']=output
output=[]
i=0
for x in data.Sensing:
    if(x> ssn- 2 * sdssn)and(x < ssn+ 2 * sdssn):
        i=i+1
        if(x> ssn-sdssn)and(x < ssn+sdssn):
          i=i+2    
          if(x> ssn-0.5*sdssn)and(x < ssn+0.5*sdssn):
            i=i+1
            if(x==ssn):
             i=i+1
    output.append(i)  
    i=0          
data['CTSensing']=output
output=[]
i=0
for x in data.Sound:
    if(x> ss- 2 * sdss)and(x < ss+ 2 * sdss):
        i=i+1
        if(x> ss-sdss)and(x < ss+sdss):
          i=i+2
          if(x> ss-0.5*sdss)and(x < ss+0.5*sdss):
            i=i+1    
            if(x==ss):
             i=i+1
    output.append(i)  
    i=0          
data['CTSound']=output
output=[]
i=0
for x in data.Events:
    if(x> se- 2 * sdse)and(x < se+ 2 * sdse):
        i=i+1
        if(x> se-sdse)and(x < se+sdse):
          i=i+2 
          if(x> se-0.5*sdse)and(x < se+0.5*sdse):
            i=i+1   
            if(x==se):
             i=i+1
    output.append(i)  
    i=0          
data['CTEvents']=output
output=[]
i=0
for x in data.Control:
    if(x> sc- 2 * sdsc)and(x < sc+ 2 * sdsc):
        i=i+1
        if(x> sc-sdsc)and(x < sc+sdsc):
           i=i+2    
           if(x> sc-0.5*sdsc)and(x < sc+0.5*sdsc):
             i=i+1
             if(x==sc):
              i=i+1
    output.append(i)  
    i=0          
data['CTControl']=output
output=[]
i=0
for x in data.Operators:
    if(x> so- 2 * sdso)and(x < so+ 2 * sdso):
        i=i+1
        if(x> so-sdso)and(x < so+sdso):
          i=i+2    
          if(x> so-0.5*sdso)and(x < so+0.5*sdso):
             i=i+1
             if(x==so):
               i=i+1
    output.append(i)  
    i=0          
data['CTOperators']=output
output=[]
i=0
for x in data.Variables:
    if(x> sv- 2 * sdsv)and(x < sv+ 2 * sdsv):
        i=i+1
        if(x> sv-sdsv)and(x < sv+sdsv):
          i=i+2   
          if(x> sv-0.5*sdsv)and(x < sv+0.5*sdsv):
            i=i+1
            if(x==sv):
             i=i+1
    output.append(i)  
    i=0          
data['CTVariables']=output
output=[]
i=0
for x in data.Myblocks:
    if(x> smb- 2 * sdsmb)and(x < smb+ 2 * sdsmb):
        i=i+1
        if(x> smb-sdsmb)and(x < smb+sdsmb):
          i=i+2    
          if(x> smb-0.5*sdsmb)and(x < smb+0.5*sdsmb):
            i=i+1
            if(x==smb):
             i=i+1
    output.append(i)  
    i=0          
data['CTMyblocks']=output
output=[]
i=0
for x in data.TotalCommands:
    if(x> stc- 2 * sdstc)and(x < stc+ 2 * sdstc):
        i=i+1
        if(x> stc-sdstc)and(x < stc+sdstc):
          i=i+2    
          if(x> stc-0.5*sdstc)and(x < stc+0.5*sdstc):
            i=i+1
            if(x==stc):
             i=i+1
    output.append(i)  
    i=0          
data['CTTotalCommands']=output
data.to_csv(r'/CTGame10.csv')
# Out:
#
# Motion
#
# Looks
#
# Sound
#
# Events
#
# Control
#
# Sensing
#
# Operators
#
# Variables
#
# MyBlocks
# 5.1375
# 4.8125
# 7.6625
# 3.225
# 2.25
# 4.9625
# 1.4875
# 1.675
# 1.6962025316455696
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0eb0a2d9-c6dd-4a7f-b411-ab4b7ca0fbc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...
