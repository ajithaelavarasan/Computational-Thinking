# %% [markdown]
# <a href="https://colab.research.google.com/github/ajithaelavarasan/Computational-Thinking/blob/main/DATA_VISUALIZATION_OF_EACH_GAME_POLAR_PLOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DATA VISUALIZATION OF  EACH GAME
import plotly.graph_objects as go
import pandas as pd
import sys 
from termcolor import colored, cprint
print_red_on_blue = lambda x: cprint(x,'red', 'on_blue') 
print_red_on_blue('  ')
print('Motion')
print_red_on_green= lambda x: cprint(x,'red', 'on_green') 
print_red_on_green('  ')
print('Looks')
print_red_on_red = lambda x: cprint(x,'red', 'on_red') 
print_red_on_red('  ')
print('Sound')
print_red_on_cyan = lambda x: cprint(x,'red', 'on_cyan') 
print_red_on_cyan('  ')
print('Events')
print_red_on_magenta = lambda x: cprint(x,'red', 'on_magenta') 
print_red_on_magenta('  ')
print('Control')
print_red_on_grey = lambda x: cprint(x,'red', 'on_grey') 
print_red_on_grey('  ')
print('Sensing')
print_red_on_yellow = lambda x: cprint(x,'red', 'on_yellow') 
print_red_on_yellow('  ')
print('Operators')
print_red_on_white = lambda x: cprint(x,'red', 'on_white') 
print_red_on_white('  ')
print('Variables')
print_red_on_cyan = lambda x: cprint(x,'red', 'on_cyan') 
print_red_on_cyan('  ')
print('MyBlocks')

# Game1
data = pd.read_csv('/game1.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
se=data.Events.mean(axis=0)
print(se)
sc=data.Control.mean(axis=0)
print(sc)
ss=data.Sound.mean(axis=0)
print(ss)
sl=data.Looks.mean(axis=0)
print(sl)
ssn=data.Sensing.mean(axis=0)
print(ssn)
so=data.Operators.mean(axis=0)
print(so)
sv=data.Variables.mean(axis=0)
print(sv)
smb=data.Myblocks.mean(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
 name= 'radius=8'
 ))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 8], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 2
data = pd.read_csv('/game2.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
se=data.Events.mean(axis=0)
print(se)
sc=data.Control.mean(axis=0)
print(sc)
ss=data.Sound.mean(axis=0)
print(ss)
sl=data.Looks.mean(axis=0)
print(sl)
ssn=data.Sensing.mean(axis=0)
print(ssn)
so=data.Operators.mean(axis=0)
print(so)
sv=data.Variables.mean(axis=0)
print(sv)
smb=data.Myblocks.mean(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
 name= 'radius=20'

    #opacity=0.8
))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 20], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 3
data = pd.read_csv('/game3.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
se=data.Events.mean(axis=0)
print(se)
sc=data.Control.mean(axis=0)
print(sc)
ss=data.Sound.mean(axis=0)
print(ss)
sl=data.Looks.mean(axis=0)
print(sl)
ssn=data.Sensing.mean(axis=0)
print(ssn)
so=data.Operators.mean(axis=0)
print(so)
sv=data.Variables.mean(axis=0)
print(sv)
smb=data.Myblocks.mean(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=15'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 15], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 4
data = pd.read_csv('/game4.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
se=data.Events.mean(axis=0)
print(se)
sc=data.Control.mean(axis=0)
print(sc)
ss=data.Sound.mean(axis=0)
print(ss)
sl=data.Looks.mean(axis=0)
print(sl)
ssn=data.Sensing.mean(axis=0)
print(ssn)
so=data.Operators.mean(axis=0)
print(so)
sv=data.Variables.mean(axis=0)
print(sv)
smb=data.Myblocks.mean(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=27'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 27], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 5
data = pd.read_csv('/game5.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
se=data.Events.mean(axis=0)
print(se)
sc=data.Control.mean(axis=0)
print(sc)
ss=data.Sound.mean(axis=0)
print(ss)
sl=data.Looks.mean(axis=0)
print(sl)
ssn=data.Sensing.mean(axis=0)
print(ssn)
so=data.Operators.mean(axis=0)
print(so)
sv=data.Variables.mean(axis=0)
print(sv)
smb=data.Myblocks.mean(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=25'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 25], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 6
data = pd.read_csv('/game6.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
se=data.Events.mean(axis=0)
print(se)
sc=data.Control.mean(axis=0)
print(sc)
ss=data.Sound.mean(axis=0)
print(ss)
sl=data.Looks.mean(axis=0)
print(sl)
ssn=data.Sensing.mean(axis=0)
print(ssn)
so=data.Operators.mean(axis=0)
print(so)
sv=data.Variables.mean(axis=0)
print(sv)
smb=data.Myblocks.mean(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=50'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 50], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 7
data = pd.read_csv('/game7.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
se=data.Events.mean(axis=0)
print(se)
sc=data.Control.mean(axis=0)
print(sc)
ss=data.Sound.mean(axis=0)
print(ss)
sl=data.Looks.mean(axis=0)
print(sl)
ssn=data.Sensing.mean(axis=0)
print(ssn)
so=data.Operators.mean(axis=0)
print(so)
sv=data.Variables.mean(axis=0)
print(sv)
smb=data.Myblocks.mean(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=150'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 40], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 8
data = pd.read_csv('/game8.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
se=data.Events.mean(axis=0)
print(se)
sc=data.Control.mean(axis=0)
print(sc)
ss=data.Sound.mean(axis=0)
print(ss)
sl=data.Looks.mean(axis=0)
print(sl)
ssn=data.Sensing.mean(axis=0)
print(ssn)
so=data.Operators.mean(axis=0)
print(so)
sv=data.Variables.mean(axis=0)
print(sv)
smb=data.Myblocks.mean(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=60'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 60], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 9
data = pd.read_csv('/game9.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
se=data.Events.mean(axis=0)
print(se)
sc=data.Control.mean(axis=0)
print(sc)
ss=data.Sound.mean(axis=0)
print(ss)
sl=data.Looks.mean(axis=0)
print(sl)
ssn=data.Sensing.mean(axis=0)
print(ssn)
so=data.Operators.mean(axis=0)
print(so)
sv=data.Variables.mean(axis=0)
print(sv)
smb=data.Myblocks.mean(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=10'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 10], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Game 10
data = pd.read_csv('/game10.csv')  
sm=data.Motion.mean(axis=0)
print(sm)
se=data.Events.mean(axis=0)
print(se)
sc=data.Control.mean(axis=0)
print(sc)
ss=data.Sound.mean(axis=0)
print(ss)
sl=data.Looks.mean(axis=0)
print(sl)
ssn=data.Sensing.mean(axis=0)
print(ssn)
so=data.Operators.mean(axis=0)
print(so)
sv=data.Variables.mean(axis=0)
print(sv)
smb=data.Myblocks.mean(axis=0)
print(smb)
fig = go.Figure(go.Barpolar(
    r=[sm,sl,ss,se,sc,ssn,so,sv,smb],
    theta=[0, 40, 80, 120, 160, 200, 240,280,320],
    width=[15,15,15,15,15,15,15,15,15],
    marker_color=["blue", 'green', 'red', 'cyan', 'magenta', 'grey', 'yellow','White','cyan'],
    marker_line_color="black",
    marker_line_width=2,
    #opacity=0.8
     name= 'radius=150'

))

fig.update_layout(
    template=None,
    polar = dict(
        radialaxis = dict(range=[0, 100], showticklabels=False, ticks=''),
        angularaxis = dict(showticklabels=False, ticks='')
    )
)

fig.show()
# Out:
#
# Motion
#
# Looks
#
# Sound
#
# Events
#
# Control
#
# Sensing
#
# Operators
#
# Variables
#
# MyBlocks
# 5.1375
# 4.8125
# 7.6625
# 3.225
# 2.25
# 4.9625
# 1.4875
# 1.675
# 1.6962025316455696
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="66dbba86-408e-4074-8519-5ec97bd176b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("66dbba86-408e-4074-8519-5ec97bd176b1")) {
#                     Plotly.newPlot(
#                         '66dbba86-408e-4074-8519-5ec97bd176b1',
#                         [{"marker": {"color": ["blue", "green", "red", "cyan", "magenta", "grey", "yellow", "White", "cyan"], "line": {"color": "black", "width": 2}}, "name": "radius=8", "r": [5.1375, 2.25, 3.225, 4.8125, 7.6625, 4.9625, 1.4875, 1.675, 1.6962025316455696], "theta": [0, 40, 80, 120, 160, 200, 240, 280, 320], "type": "barpolar", "width": [15, 15, 15, 15, 15, 15, 15, 15, 15]}],
#                         {"polar": {"angularaxis": {"showticklabels": false, "ticks": ""}, "radialaxis": {"range": [0, 8], "showticklabels": false, "ticks": ""}}, "template": {}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('66dbba86-408e-4074-8519-5ec97bd176b1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#
#             </script>
#         </div>
# </body>
# </html>
# 7.144444444444445
# 11.577777777777778
# 12.7
# 6.788888888888889
# 18.833333333333332
# 7.988888888888889
# 0.5222222222222223
# 10.533333333333333
# 3.511111111111111
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="eab53647-6acf-41d5-ad27-cb0f6161d192" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eab53647-6acf-41d5-ad27-cb0f6161d192")) {
#                     Plotly.newPlot(
#                         'eab53647-6acf-41d5-ad27-cb0f6161d192',
#                         [{"marker": {"color": ["blue", "green", "red", "cyan", "magenta", "grey", "yellow", "White", "cyan"], "line": {"color": "black", "width": 2}}, "name": "radius=20", "r": [7.144444444444445, 18.833333333333332, 6.788888888888889, 11.577777777777778, 12.7, 7.988888888888889, 0.5222222222222223, 10.533333333333333, 3.511111111111111], "theta": [0, 40, 80, 120, 160, 200, 240, 280, 320], "type": "barpolar", "width": [15, 15, 15, 15, 15, 15, 15, 15, 15]}],
#                         {"polar": {"angularaxis": {"showticklabels": false, "ticks": ""}, "radialaxis": {"range": [0, 20], "showticklabels": false, "ticks": ""}}, "template": {}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('eab53647-6acf-41d5-ad27-cb0f6161d192');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#
#             </script>
#         </div>
# </body>
# </html>
# 2.7111111111111112
# 9.544444444444444
# 9.444444444444445
# 11.233333333333333
# 6.011111111111111
# 5.688888888888889
# 2.8666666666666667
# 12.466666666666667
# 1.9111111111111112
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="056d9dda-ba44-48e6-a63d-b647ccafa941" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("056d9dda-ba44-48e6-a63d-b647ccafa941")) {
#                     Plotly.newPlot(
#                         '056d9dda-ba44-48e6-a63d-b647ccafa941',
#                         [{"marker": {"color": ["blue", "green", "red", "cyan", "magenta", "grey", "yellow", "White", "cyan"], "line": {"color": "black", "width": 2}}, "name": "radius=15", "r": [2.7111111111111112, 6.011111111111111, 11.233333333333333, 9.544444444444444, 9.444444444444445, 5.688888888888889, 2.8666666666666667, 12.466666666666667, 1.9111111111111112], "theta": [0, 40, 80, 120, 160, 200, 240, 280, 320], "type": "barpolar", "width": [15, 15, 15, 15, 15, 15, 15, 15, 15]}],
#                         {"polar": {"angularaxis": {"showticklabels": false, "ticks": ""}, "radialaxis": {"range": [0, 15], "showticklabels": false, "ticks": ""}}, "template": {}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('056d9dda-ba44-48e6-a63d-b647ccafa941');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#
#             </script>
#         </div>
# </body>
# </html>
# 10.855555555555556
# 6.444444444444445
# 25.1
# 2.9
# 3.588888888888889
# 8.88888888888889
# 8.855555555555556
# 11.344444444444445
# 6.544444444444444
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c0fdb7c3-49b4-4f05-86b9-ab945e5cb831" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c0fdb7c3-49b4-4f05-86b9-ab945e5cb831")) {
#                     Plotly.newPlot(
#                         'c0fdb7c3-49b4-4f05-86b9-ab945e5cb831',
#                         [{"marker": {"color": ["blue", "green", "red", "cyan", "magenta", "grey", "yellow", "White", "cyan"], "line": {"color": "black", "width": 2}}, "name": "radius=27", "r": [10.855555555555556, 3.588888888888889, 2.9, 6.444444444444445, 25.1, 8.88888888888889, 8.855555555555556, 11.344444444444445, 6.544444444444444], "theta": [0, 40, 80, 120, 160, 200, 240, 280, 320], "type": "barpolar", "width": [15, 15, 15, 15, 15, 15, 15, 15, 15]}],
#                         {"polar": {"angularaxis": {"showticklabels": false, "ticks": ""}, "radialaxis": {"range": [0, 27], "showticklabels": false, "ticks": ""}}, "template": {}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c0fdb7c3-49b4-4f05-86b9-ab945e5cb831');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#
#             </script>
#         </div>
# </body>
# </html>
# 9.2
# 21.855555555555554
# 13.466666666666667
# 5.011111111111111
# 23.844444444444445
# 18.0
# 10.28888888888889
# 9.877777777777778
# 3.8444444444444446
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="559d9e16-2f6b-4aad-8442-cb3297a30aa2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("559d9e16-2f6b-4aad-8442-cb3297a30aa2")) {
#                     Plotly.newPlot(
#                         '559d9e16-2f6b-4aad-8442-cb3297a30aa2',
#                         [{"marker": {"color": ["blue", "green", "red", "cyan", "magenta", "grey", "yellow", "White", "cyan"], "line": {"color": "black", "width": 2}}, "name": "radius=25", "r": [9.2, 23.844444444444445, 5.011111111111111, 21.855555555555554, 13.466666666666667, 18.0, 10.28888888888889, 9.877777777777778, 3.8444444444444446], "theta": [0, 40, 80, 120, 160, 200, 240, 280, 320], "type": "barpolar", "width": [15, 15, 15, 15, 15, 15, 15, 15, 15]}],
#                         {"polar": {"angularaxis": {"showticklabels": false, "ticks": ""}, "radialaxis": {"range": [0, 25], "showticklabels": false, "ticks": ""}}, "template": {}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('559d9e16-2f6b-4aad-8442-cb3297a30aa2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#
#             </script>
#         </div>
# </body>
# </html>
# 15.031746031746032
# 24.793650793650794
# 43.53968253968254
# 3.9206349206349205
# 38.857142857142854
# 14.26984126984127
# 24.349206349206348
# 29.0
# 6.174603174603175
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7bbf793a-ecb3-437d-87c0-44ffabc1cd24" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7bbf793a-ecb3-437d-87c0-44ffabc1cd24")) {
#                     Plotly.newPlot(
#                         '7bbf793a-ecb3-437d-87c0-44ffabc1cd24',
#                         [{"marker": {"color": ["blue", "green", "red", "cyan", "magenta", "grey", "yellow", "White", "cyan"], "line": {"color": "black", "width": 2}}, "name": "radius=50", "r": [15.031746031746032, 38.857142857142854, 3.9206349206349205, 24.793650793650794, 43.53968253968254, 14.26984126984127, 24.349206349206348, 29.0, 6.174603174603175], "theta": [0, 40, 80, 120, 160, 200, 240, 280, 320], "type": "barpolar", "width": [15, 15, 15, 15, 15, 15, 15, 15, 15]}],
#                         {"polar": {"angularaxis": {"showticklabels": false, "ticks": ""}, "radialaxis": {"range": [0, 50], "showticklabels": false, "ticks": ""}}, "template": {}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('7bbf793a-ecb3-437d-87c0-44ffabc1cd24');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#
#             </script>
#         </div>
# </body>
# </html>
# 1.9425287356321839
# 8.71264367816092
# 36.57471264367816
# 1.7126436781609196
# 3.7011494252873565
# 3.896551724137931
# 142.8735632183908
# 213.45977011494253
# 2.4597701149425286
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d0d67294-42b8-4b55-bfb7-2bdd408fd41c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d0d67294-42b8-4b55-bfb7-2bdd408fd41c")) {
#                     Plotly.newPlot(
#                         'd0d67294-42b8-4b55-bfb7-2bdd408fd41c',
#                         [{"marker": {"color": ["blue", "green", "red", "cyan", "magenta", "grey", "yellow", "White", "cyan"], "line": {"color": "black", "width": 2}}, "name": "radius=150", "r": [1.9425287356321839, 3.7011494252873565, 1.7126436781609196, 8.71264367816092, 36.57471264367816, 3.896551724137931, 142.8735632183908, 213.45977011494253, 2.4597701149425286], "theta": [0, 40, 80, 120, 160, 200, 240, 280, 320], "type": "barpolar", "width": [15, 15, 15, 15, 15, 15, 15, 15, 15]}],
#                         {"polar": {"angularaxis": {"showticklabels": false, "ticks": ""}, "radialaxis": {"range": [0, 40], "showticklabels": false, "ticks": ""}}, "template": {}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d0d67294-42b8-4b55-bfb7-2bdd408fd41c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#
#             </script>
#         </div>
# </body>
# </html>
# 27.964912280701753
# 13.052631578947368
# 26.087719298245613
# 10.894736842105264
# 30.0
# 9.824561403508772
# 33.59649122807018
# 56.89473684210526
# 7.894736842105263
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fd0477d4-3f99-4d12-97b6-5d3f3a297305" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fd0477d4-3f99-4d12-97b6-5d3f3a297305")) {
#                     Plotly.newPlot(
#                         'fd0477d4-3f99-4d12-97b6-5d3f3a297305',
#                         [{"marker": {"color": ["blue", "green", "red", "cyan", "magenta", "grey", "yellow", "White", "cyan"], "line": {"color": "black", "width": 2}}, "name": "radius=60", "r": [27.964912280701753, 30.0, 10.894736842105264, 13.052631578947368, 26.087719298245613, 9.824561403508772, 33.59649122807018, 56.89473684210526, 7.894736842105263], "theta": [0, 40, 80, 120, 160, 200, 240, 280, 320], "type": "barpolar", "width": [15, 15, 15, 15, 15, 15, 15, 15, 15]}],
#                         {"polar": {"angularaxis": {"showticklabels": false, "ticks": ""}, "radialaxis": {"range": [0, 60], "showticklabels": false, "ticks": ""}}, "template": {}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('fd0477d4-3f99-4d12-97b6-5d3f3a297305');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#
#             </script>
#         </div>
# </body>
# </html>
# 3.422222222222222
# 3.466666666666667
# 6.855555555555555
# 2.8777777777777778
# 5.522222222222222
# 4.933333333333334
# 3.922222222222222
# 1.9
# 1.4555555555555555
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="02af583b-692d-4269-ace1-bbc5e4b5c94c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("02af583b-692d-4269-ace1-bbc5e4b5c94c")) {
#                     Plotly.newPlot(
#                         '02af583b-692d-4269-ace1-bbc5e4b5c94c',
#                         [{"marker": {"color": ["blue", "green", "red", "cyan", "magenta", "grey", "yellow", "White", "cyan"], "line": {"color": "black", "width": 2}}, "name": "radius=10", "r": [3.422222222222222, 5.522222222222222, 2.8777777777777778, 3.466666666666667, 6.855555555555555, 4.933333333333334, 3.922222222222222, 1.9, 1.4555555555555555], "theta": [0, 40, 80, 120, 160, 200, 240, 280, 320], "type": "barpolar", "width": [15, 15, 15, 15, 15, 15, 15, 15, 15]}],
#                         {"polar": {"angularaxis": {"showticklabels": false, "ticks": ""}, "radialaxis": {"range": [0, 10], "showticklabels": false, "ticks": ""}}, "template": {}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('02af583b-692d-4269-ace1-bbc5e4b5c94c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#
#             </script>
#         </div>
# </body>
# </html>
# 27.363636363636363
# 10.761363636363637
# 41.29545454545455
# 7.465909090909091
# 10.454545454545455
# 22.238636363636363
# 203.0
# 86.02272727272727
# 8.340909090909092
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c9121d4a-1e36-4dec-9af6-e7d0b05fc70c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c9121d4a-1e36-4dec-9af6-e7d0b05fc70c")) {
#                     Plotly.newPlot(
#                         'c9121d4a-1e36-4dec-9af6-e7d0b05fc70c',
#                         [{"marker": {"color": ["blue", "green", "red", "cyan", "magenta", "grey", "yellow", "White", "cyan"], "line": {"color": "black", "width": 2}}, "name": "radius=150", "r": [27.363636363636363, 10.454545454545455, 7.465909090909091, 10.761363636363637, 41.29545454545455, 22.238636363636363, 203.0, 86.02272727272727, 8.340909090909092], "theta": [0, 40, 80, 120, 160, 200, 240, 280, 320], "type": "barpolar", "width": [15, 15, 15, 15, 15, 15, 15, 15, 15]}],
#                         {"polar": {"angularaxis": {"showticklabels": false, "ticks": ""}, "radialaxis": {"range": [0, 100], "showticklabels": false, "ticks": ""}}, "template": {}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c9121d4a-1e36-4dec-9af6-e7d0b05fc70c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#
#             </script>
#         </div>
# </body>
# </html>
