# %% [markdown]
# <a href="https://colab.research.google.com/github/ajithaelavarasan/Computational-Thinking/blob/main/KMEAN_SC__CORRELATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#KMEANS CLUSTERING SUMCOMMANDS
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
dataset= pd.read_csv('/dataset_after_data_aggregation.csv')
print(dataset.info())
X=dataset.iloc[:, [0,15]].values
 
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TotalCommands    825 non-null    int64
#  1   Game             825 non-null    int64
#  2   Period           825 non-null    int64
#  3   Sprites          825 non-null    int64
#  4   BackDrops        825 non-null    int64
#  5   Costumes         825 non-null    int64
#  6   Motion           825 non-null    int64
#  7   Looks            825 non-null    int64
#  8   Sound            825 non-null    int64
#  9   Events           825 non-null    int64
#  10  Control          825 non-null    int64
#  11  Sensing          825 non-null    int64
#  12  Operators        825 non-null    int64
#  13  Variables        825 non-null    int64
#  14  Myblocks         824 non-null    float64
#  15  SumCommands      825 non-null    int64
#  16  BinaryMotion     825 non-null    int64
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
dataset= pd.read_csv('/game1.csv')
X=dataset.iloc[:, [1,16]].values
 
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
dataset= pd.read_csv('/game2.csv')
X=dataset.iloc[:, [1,16]].values
 
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
dataset= pd.read_csv('/game3.csv')
X=dataset.iloc[:, [1,16]].values
 
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
dataset= pd.read_csv('/game4.csv')
X=dataset.iloc[:, [1,16]].values
 
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
dataset= pd.read_csv('/game5.csv')
X=dataset.iloc[:, [1,16]].values
 
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
dataset= pd.read_csv('/game6.csv')
X=dataset.iloc[:, [1,16]].values
 
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
dataset= pd.read_csv('/game7.csv')
X=dataset.iloc[:, [1,16]].values
 
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
dataset= pd.read_csv('/game8.csv')
X=dataset.iloc[:, [1,16]].values
 
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
dataset= pd.read_csv('/game9.csv')
X=dataset.iloc[:, [1,16]].values
 
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
dataset= pd.read_csv('/game10.csv')
X=dataset.iloc[:, [1,16]].values
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, init ='k-means++', max_iter=300, n_init=10,random_state=0 )
y_kmeans = kmeans.fit_predict(X)
dataset['cluster']=y_kmeans
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], s=10, c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], s=10, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], s=10, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], s=10, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], s=10, c='magenta', label ='Cluster 5')

# %%
#CORRELATION ANALYSIS
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
import seaborn as sns
dataset= pd.read_csv('/dataset_after_data_aggregation.csv')
dataset1= pd.read_csv('/game1.csv')
dataset2= pd.read_csv('/game2.csv')
dataset3= pd.read_csv('/game3.csv')
dataset4= pd.read_csv('/game4.csv')
dataset5= pd.read_csv('/game5.csv')
dataset6= pd.read_csv('/game6.csv')
dataset7= pd.read_csv('/game7.csv')
dataset8= pd.read_csv('/game8.csv')
dataset9= pd.read_csv('/game9.csv')
dataset10= pd.read_csv('/game10.csv')

# Here we create a figure instance, and two subplots
fig = plt.figure(figsize = (20,20)) # width x height
ax1 = fig.add_subplot(4, 3, 1) # row, column, position
ax2 = fig.add_subplot(4, 3, 2)
ax3 = fig.add_subplot(4, 3, 3)
ax4 = fig.add_subplot(4, 3, 4)
ax5 = fig.add_subplot(4, 3, 5)
ax6 = fig.add_subplot(4, 3, 6)
ax7 = fig.add_subplot(4, 3, 7)
ax8 = fig.add_subplot(4, 3, 8)
ax9 = fig.add_subplot(4, 3, 9)
ax10 = fig.add_subplot(4, 3, 10)
ax11 = fig.add_subplot(4, 3, 11)


# We use ax parameter to tell seaborn which subplot to use for this plot
sns.heatmap(data=dataset[['SumCommands','Motion','Looks','Events','Sensing','Control','Sound','Operators','Variables','Myblocks']].corr(), ax=ax1,  square=True, cbar_kws={'shrink': .4}, annot=False, annot_kws={'fontsize': 12})
sns.heatmap(data=dataset1[['SumCommands','Motion','Looks','Events','Sensing','Control','Sound','Operators','Variables','Myblocks']].corr(), ax=ax2,  square=True, cbar_kws={'shrink': .4}, annot=False, annot_kws={'fontsize': 12})
sns.heatmap(data=dataset2[['SumCommands','Motion','Looks','Events','Sensing','Control','Sound','Operators','Variables','Myblocks']].corr(), ax=ax3,  square=True, cbar_kws={'shrink': .4}, annot=False, annot_kws={'fontsize': 12})
sns.heatmap(data=dataset3[['SumCommands','Motion','Looks','Events','Sensing','Control','Sound','Operators','Variables','Myblocks']].corr(), ax=ax4,  square=True, cbar_kws={'shrink': .4}, annot=False, annot_kws={'fontsize': 12})
sns.heatmap(data=dataset4[['SumCommands','Motion','Looks','Events','Sensing','Control','Sound','Operators','Variables','Myblocks']].corr(), ax=ax5,  square=True, cbar_kws={'shrink': .4}, annot=False, annot_kws={'fontsize': 12})
sns.heatmap(data=dataset5[['SumCommands','Motion','Looks','Events','Sensing','Control','Sound','Operators','Variables','Myblocks']].corr(), ax=ax6,  square=True, cbar_kws={'shrink': .4}, annot=False, annot_kws={'fontsize': 12})
sns.heatmap(data=dataset6[['SumCommands','Motion','Looks','Events','Sensing','Control','Sound','Operators','Variables','Myblocks']].corr(), ax=ax7,  square=True, cbar_kws={'shrink': .4}, annot=False, annot_kws={'fontsize': 12})
sns.heatmap(data=dataset7[['SumCommands','Motion','Looks','Events','Sensing','Control','Sound','Operators','Variables','Myblocks']].corr(), ax=ax8,  square=True, cbar_kws={'shrink': .4}, annot=False, annot_kws={'fontsize': 12})
sns.heatmap(data=dataset8[['SumCommands','Motion','Looks','Events','Sensing','Control','Sound','Operators','Variables','Myblocks']].corr(), ax=ax9,  square=True, cbar_kws={'shrink': .4}, annot=False, annot_kws={'fontsize': 12})
sns.heatmap(data=dataset9[['SumCommands','Motion','Looks','Events','Sensing','Control','Sound','Operators','Variables','Myblocks']].corr(), ax=ax10,  square=True, cbar_kws={'shrink': .4}, annot=False, annot_kws={'fontsize': 12})
sns.heatmap(data=dataset10[['SumCommands','Motion','Looks','Events','Sensing','Control','Sound','Operators','Variables','Myblocks']].corr(), ax=ax11,  square=True, cbar_kws={'shrink': .4}, annot=False, annot_kws={'fontsize': 12})
