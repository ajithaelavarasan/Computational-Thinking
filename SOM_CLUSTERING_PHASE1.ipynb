# %% [markdown]
# <a href="https://colab.research.google.com/github/ajithaelavarasan/Computational-Thinking/blob/main/SOM_CLUSTERING_PHASE1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SOMCLUSTERING PHASE1
from minisom import MiniSom    
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set_theme()
from sklearn.datasets import load_digits
from pylab import plot,axis,show,pcolor,colorbar,bone
data= pd.read_csv('/dataset_after_data_aggregation.csv')
som = MiniSom(5, 5, 5, sigma=0.5, learning_rate=0.1)
X=dataset.iloc[:, [0,1,3,4,15]].values
labels=X
som.random_weights_init(X)
print("Initiating SOM.")
#som.train_random(X,100) 
som.train_batch(X,100) 
print("\n. SOM Processing Complete")
pcolor(som.distance_map().T) 
colorbar()
print(som.distance_map().T)
markers = ['o', '1', '^', 'h', 'X', 's', 'p', 'P', 'D', '*']
colors = ["r", "g", "b", "y", "c", (0,0.1,0.8), (1,0.5,0), (1,1,0.3), "m", (0.4,0.6,0)]
y=[]
for x in data.Game:
   y.append(x)
for x in range(0,10):
     print(x,markers[x])
pcolor(som.distance_map().T) 
j=0.0001
for i,x in enumerate(X):
    w=som.winner(x)
    plot(w[0]+j,
         w[1]+j,
        markers[y[i]-1],
        markeredgecolor=colors[y[i]-1],markerfacecolor='None',markersize=10,markeredgewidth=2)
    j=j+0.0009
  
show()
pcolor(som.distance_map().T) 
j=0.001
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[1]==1):
      plot(w[0]+j,
         w[1]+j,
        markers[0],
        markeredgecolor=colors[0],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.009
     
show()
pcolor(som.distance_map().T) 
j=0.001
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[1]==2):
      plot(w[0]+j,
         w[1]+j,
        markers[1],
        markeredgecolor=colors[1],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.009
    
            
show()
pcolor(som.distance_map().T) 
j=0.001
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[1]==3):
      plot(w[0]+j,
         w[1]+j,
        markers[2],
        markeredgecolor=colors[2],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.009
     
show()
pcolor(som.distance_map().T) 
j=0.001
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[1]==4):
      plot(w[0]+j,
         w[1]+j,
        markers[3],
        markeredgecolor=colors[3],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.009
     
show()
pcolor(som.distance_map().T) 
j=0.001
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[1]==5):
      plot(w[0]+j,
         w[1]+j,
        markers[4],
        markeredgecolor=colors[4],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.009
      
show()
pcolor(som.distance_map().T) 
j=0.001
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[1]==6):
      plot(w[0]+j,
         w[1]+j,
        markers[5],
        markeredgecolor=colors[5],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.009       
show()
pcolor(som.distance_map().T) 
j=0.001
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[1]==7):
      plot(w[0]+j,
         w[1]+j,
        markers[6],
        markeredgecolor=colors[6],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.009
     
            
show()
pcolor(som.distance_map().T) 
j=0.001
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[1]==8):
      plot(w[0]+j,
         w[1]+j,
        markers[7],
        markeredgecolor=colors[7],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.009
    
show()
pcolor(som.distance_map().T) 
j=0.001
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[1]==9):
      plot(w[0]+j,
         w[1]+j,
        markers[8],
        markeredgecolor=colors[8],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.009
    
show()
pcolor(som.distance_map().T) 
j=0.001
 
  
for i,x in enumerate(X):
    w=som.winner(x)
    if(  x[1]==10):
      plot(w[0]+j,
         w[1]+j,
        markers[9],
        markeredgecolor=colors[9],markerfacecolor='None',markersize=10,markeredgewidth=2)
      j=j+0.009
     
show()
# Out:
# Initiating SOM.
#
# . SOM Processing Complete
# [[0.17116831 0.45612215 0.44120283 0.31041855 0.05859156]
#  [0.33559782 0.55217108 0.94818466 0.51083291 0.17111326]
#  [0.26954297 1.         0.73266379 0.66830984 0.53884157]
#  [0.36063637 0.73955181 0.77436784 0.73356437 0.57789284]
#  [0.24817821 0.46546134 0.71987066 0.3636889  0.32420895]]
# 0 o
# 1 1
# 2 ^
# 3 h
# 4 X
# 5 s
# 6 p
# 7 P
# 8 D
# 9 *
